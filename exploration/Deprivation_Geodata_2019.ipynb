# %%
import pandas as pd
pd.set_option('display.max_columns', 100)
import numpy as np
from IPython.display import display, HTML


# %matplotlib inline
import random
import matplotlib.pyplot as plt
import seaborn as sns

import geopandas as gpd
import shapely as sp
import shapely.geometry as sgeom
import cartopy.io.shapereader as shpreader

import os

# %% [markdown]
# ## Contents
#
# * [Approach](#section_approach)
# * [Import Deprivation Index Data: LSOA Level](#section_depriv_lsoa)
# * [Import Geo-Data: LSOA Level](## Import-Geo-Data:-LSOA-Level)

# %% [markdown]
# <a id="section_approach"></a>
#
# ---
#
# ## Approach
#
#
# #### Geo-data
#
# There are 3 levels of administrative geo-data in England
#
# * Local Authority Districts (LAD)
#     * [geodata source](http://geoportal.statistics.gov.uk/datasets/local-authority-districts-december-2011-gb-bgc) - 2011 boundaries (because this is what the deprivation data is officially matched with), resolution: generalised, not WGS84
# * Wards
#     * [geodata source](http://geoportal.statistics.gov.uk/datasets/wards-december-2017-generalised-clipped-boundaries-in-great-britain) - 2017 boundaries, resolution: generalised, not WGS84
# * Lower Super Output Areas (LSOA)
#     * [geodata source](http://geoportal.statistics.gov.uk/datasets/da831f80764346889837c72508f046fa_2) - 2011 boundaries (this is the latest year for LSOAs), resolution: generalised, not WGS84
#
#
# Note for some confusing terms in the geo-datasets' names:
#
# * BFC Boundary - Full resolution, Clipped to the coastline
# * BFE Boundary - Full resolution, Extent of the realm
# * BGC Boundary - Generalised (20m), Clipped to the coastline
# * BGE Boundary - Generalised (20m), Extent of the realm
# * BSC Boundary - Super Generalised (200m), Clipped to the coastline
# * BSE Boundary - Super Generalised (200m), Extent of the realm
#
# #### Deprivation data
#
# Deprivation index data is at the LSOA level, but is already officially aggregated at the LAD level. So we need to produce our own aggregation at the Ward level. This is made more complicated because wards and LSOAs don't usually map neatly into one another, as described in [this github issue](https://github.com/yanoak/360giving-deprivation/issues/8). A workaround is to have an [official lookup table](http://geoportal.statistics.gov.uk/datasets/lower-layer-super-output-area-2011-to-ward-2017-lookup-in-england-and-wales) that matches LSOAs (2011) to Wards (2017) using a [best fitting method](http://geoportal.statistics.gov.uk/datasets?q=Building%202011%20Census%20estimates) that relies on population weighted centroids of Output Areas.
#
# Datasets:
#
# * [LSOAs 2011 to Wards 2017 lookup table](http://geoportal.statistics.gov.uk/datasets/lower-layer-super-output-area-2011-to-ward-2017-lookup-in-england-and-wales)
# * [English Indices of Deprivation 2019 - LSOA Level (csv)](http://opendatacommunities.org/data/societal-wellbeing/imd2019/indices)
# * [English Indices of Deprivation 2019 - Summaries at Local Authority Level (csv)](http://opendatacommunities.org/data/societal-wellbeing/imd2019/indicesbyla)
# * [Other associated info/files for English Indices of Deprivation with xlsx files of LAD and LSOA level deprivation](https://www.gov.uk/government/statistics/english-indices-of-deprivation-2019)
# * [Research report](https://www.gov.uk/government/publications/english-indices-of-deprivation-2019-research-report) Section 3.3 contains guidance on how to interpret higher level geography summaries
#
# &nbsp;

# %% [markdown]
# <a id="section_depriv_lsoa"></a>
#
# ---
#
#
# ## Import Deprivation Index Data: LSOA Level
#
# Source: [Homepage](https://www.gov.uk/government/statistics/english-indices-of-deprivation-2019)
#
# [File 2: Domains of Deprivation](https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/833973/File_2_-_IoD2019_Domains_of_Deprivation.xlsx)

# %%
dp_lsoa_df = pd.read_excel('../data/deprivation/File_2_-_IoD2019_Domains_of_Deprivation.xlsx', sheet_name='IoD2019 Domains', index_col=[0])

# %%
dp_lsoa_df.columns
# Out:
# Index(['LSOA name (2011)', 'Local Authority District code (2019)',
#        'Local Authority District name (2019)',
#        'Index of Multiple Deprivation (IMD) Rank (where 1 is most deprived)',
#        'Index of Multiple Deprivation (IMD) Decile (where 1 is most deprived 10% of LSOAs)',
#        'Income Rank (where 1 is most deprived)',
#        'Income Decile (where 1 is most deprived 10% of LSOAs)',
#        'Employment Rank (where 1 is most deprived)',
#        'Employment Decile (where 1 is most deprived 10% of LSOAs)',
#        'Education, Skills and Training Rank (where 1 is most deprived)',
#        'Education, Skills and Training Decile (where 1 is most deprived 10% of LSOAs)',
#        'Health Deprivation and Disability Rank (where 1 is most deprived)',
#        'Health Deprivation and Disability Decile (where 1 is most deprived 10% of LSOAs)',
#        'Crime Rank (where 1 is most deprived)',
#        'Crime Decile (where 1 is most deprived 10% of LSOAs)',
#        'Barriers to Housing and Services Rank (where 1 is most deprived)',
#        'Barriers to Housing and Services Decile (where 1 is most deprived 10% of LSOAs)',
#        'Living Environment Rank (where 1 is most deprived)',
#        'Living Environment Decile (where 1 is most deprived 10% of LSOAs)'],
#       dtype='object')

# %%
dp_lsoa_df.rename(index=str, columns={'LSOA name (2011)' : 'LSOA2011_NM', \
        'Local Authority District code (2019)' : 'LAD2019_CD', \
        'Local Authority District name (2019)' : 'LAD2019_NM', \
        'Index of Multiple Deprivation (IMD) Rank (where 1 is most deprived)' : 'imd_rank', \
        'Index of Multiple Deprivation (IMD) Decile (where 1 is most deprived 10% of LSOAs)' : 'imd_dec', \
        'Income Rank (where 1 is most deprived)' : 'income_rank', \
        'Income Decile (where 1 is most deprived 10% of LSOAs)' : 'incom_dec', \
        'Employment Rank (where 1 is most deprived)' : 'employment_rank', \
        'Employment Decile (where 1 is most deprived 10% of LSOAs)' : 'employment_dec', \
        'Education, Skills and Training Rank (where 1 is most deprived)' : 'education_rank', \
        'Education, Skills and Training Decile (where 1 is most deprived 10% of LSOAs)' : 'education_dec', \
        'Health Deprivation and Disability Rank (where 1 is most deprived)' : 'health_rank', \
        'Health Deprivation and Disability Decile (where 1 is most deprived 10% of LSOAs)' : 'health_dec', \
        'Crime Rank (where 1 is most deprived)' : 'crime_rank', \
        'Crime Decile (where 1 is most deprived 10% of LSOAs)' : 'crime_dec', \
        'Barriers to Housing and Services Rank (where 1 is most deprived)' : 'housing_rank', \
        'Barriers to Housing and Services Decile (where 1 is most deprived 10% of LSOAs)' : 'housing_dec', \
        'Living Environment Rank (where 1 is most deprived)' : 'environment_rank', \
        'Living Environment Decile (where 1 is most deprived 10% of LSOAs)' : 'environment_dec' \
        }, inplace=True)

# %%
dp_lsoa_df.index.names = ['LSOA2011_CD']

# %%
dp_lsoa_df.head()
# Out:
#                            LSOA2011_NM LAD2019_CD            LAD2019_NM  \
# LSOA2011_CD
# E01000001          City of London 001A  E09000001        City of London
# E01000002          City of London 001B  E09000001        City of London
# E01000003          City of London 001C  E09000001        City of London
# E01000005          City of London 001E  E09000001        City of London
# E01000006    Barking and Dagenham 016A  E09000002  Barking and Dagenham
#
#              imd_rank  imd_dec  income_rank  incom_dec  employment_rank  \
# LSOA2011_CD
# E01000001       29199        9        32831         10            32742
# E01000002       30379       10        29901         10            31190
# E01000003       14915        5        18510          6            15103
# E01000005        8678        3         6029          2             7833
# E01000006       14486        5        14023          5            21692
#
#              employment_dec  education_rank  education_dec  health_rank  \
# LSOA2011_CD
# E01000001                10           32842             10        32113
# E01000002                10           32832             10        29705
# E01000003                 5           26386              9        17600
# E01000005                 3           12370              4        17907
# E01000006                 7           17511              6        21581
#
#              health_dec  crime_rank  crime_dec  housing_rank  housing_dec  \
# LSOA2011_CD
# E01000001            10       32662         10          7319            3
# E01000002            10       32789         10         11707            4
# E01000003             6       29363          9          2157            1
# E01000005             6       31059         10          2217            1
# E01000006             7       18848          6          1033            1
#
#              environment_rank  environment_dec
# LSOA2011_CD
# E01000001                7789                3
# E01000002               13070                4
# E01000003                4092                2
# E01000005                9397                3
# E01000006               10629                4

# %% [markdown]
# <a id="section_depriv_lad"></a>
#
# ---
#
# ## Import Deprivation Index Data: LAD Level
#
# Source: [Homepage](https://www.gov.uk/government/statistics/english-indices-of-deprivation-2019)
#
# [File 10: Local Authority District Summaries](https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/833995/File_10_-_IoD2019_Local_Authority_District_Summaries__lower-tier__.xlsx)
#
# The aggregation produces a lot of different measures such as ranks and ranks of ranks. We are only interested in the average score, which is weighted by the population of the LSOAs that make up the LAD

# %%
lad_vars = [
    {'sheet': 'IMD', 'col': 'IMD - Average score'},
    {'sheet': 'Income', 'col': 'Income - Average score'},
    {'sheet': 'Employment', 'col': 'Employment - Average score'},
    {'sheet': 'Education', 'col': 'Education, Skills and Training - Average score'},
    {'sheet': 'Health', 'col': 'Health Deprivation and Disability - Average score'},
    {'sheet': 'Crime', 'col': 'Crime - Average score'},
    {'sheet': 'Barriers', 'col': 'Barriers to Housing and Services - Average score'},
    {'sheet': 'Living', 'col': 'Living Environment - Average score'}
]

# %%
lad_df = pd.DataFrame()

for i, v in enumerate(lad_vars):
    #print(v['sheet'],i)
    df = pd.read_excel(
        '../data/deprivation/File_10_-_IoD2019_Local_Authority_District_Summaries__lower-tier__.xlsx',
        sheet_name=v['sheet']
    )
    df.rename(columns=lambda x: x.strip(" "), inplace=True)
    df.rename(
        index=str,
        columns={
            'Local Authority District code (2019)' : 'LAD2019_CD',
            'Local Authority District name (2019)' : 'LAD2019_NM',
            v['col'] : v['sheet']+'_avg_score',
        }, inplace=True)
    if i == 0:
        lad_df = lad_df.append(df[['LAD2019_CD','LAD2019_NM',v['sheet']+'_avg_score']])
    else:
        lad_df = pd.merge(lad_df, df[['LAD2019_CD',v['sheet']+'_avg_score']], on='LAD2019_CD',sort=True)
    
#dp_lad_df = pd.read_excel('../data/deprivation/File_10_ID2015_Local_Authority_District_Summaries.xlsx', sheet_name='ID2015 Domains', index_col=[0])

display(lad_df.head())
# Out:
#   LAD2019_CD            LAD2019_NM  IMD_avg_score  Income_avg_score  \
# 0  E06000001            Hartlepool         35.037             0.228
# 1  E06000002         Middlesbrough         40.460             0.251
# 2  E06000003  Redcar and Cleveland         29.792             0.186
# 3  E06000004      Stockton-on-Tees         25.790             0.164
# 4  E06000005            Darlington         25.657             0.153
#
#    Employment_avg_score  Education_avg_score  Health_avg_score  \
# 0                 0.185               30.255             0.869
# 1                 0.191               38.850             1.194
# 2                 0.165               27.768             0.790
# 3                 0.135               24.786             0.684
# 4                 0.128               27.402             0.532
#
#    Crime_avg_score  Barriers_avg_score  Living_avg_score
# 0            0.566              14.242             6.943
# 1            0.701              14.183            12.929
# 2            0.138              14.139             7.793
# 3           -0.111              15.870             6.007
# 4            0.558              11.942             8.800

# %%
deprivation_colums = {'IMD_avg_score':'comparison_IMD_avg_score', \
                        'Income_avg_score':'comparison_Income_avg_score', \
                        'Employment_avg_score':'comparison_Employment_avg_score', \
                        'Education_avg_score':'comparison_Education_avg_score', \
                        'Health_avg_score':'comparison_Health_avg_score', \
                        'Crime_avg_score':'comparison_Crime_avg_score', \
                        'Barriers_avg_score':'comparison_Barriers_avg_score', \
                        'Living_avg_score':'comparison_Living_avg_score' }

lad_df.rename(index=str, columns=deprivation_colums, inplace=True)

display(lad_df.head())
# Out:
#   LAD2019_CD            LAD2019_NM  comparison_IMD_avg_score  \
# 0  E06000001            Hartlepool                    35.037
# 1  E06000002         Middlesbrough                    40.460
# 2  E06000003  Redcar and Cleveland                    29.792
# 3  E06000004      Stockton-on-Tees                    25.790
# 4  E06000005            Darlington                    25.657
#
#    comparison_Income_avg_score  comparison_Employment_avg_score  \
# 0                        0.228                            0.185
# 1                        0.251                            0.191
# 2                        0.186                            0.165
# 3                        0.164                            0.135
# 4                        0.153                            0.128
#
#    comparison_Education_avg_score  comparison_Health_avg_score  \
# 0                          30.255                        0.869
# 1                          38.850                        1.194
# 2                          27.768                        0.790
# 3                          24.786                        0.684
# 4                          27.402                        0.532
#
#    comparison_Crime_avg_score  comparison_Barriers_avg_score  \
# 0                       0.566                         14.242
# 1                       0.701                         14.183
# 2                       0.138                         14.139
# 3                      -0.111                         15.870
# 4                       0.558                         11.942
#
#    comparison_Living_avg_score
# 0                        6.943
# 1                       12.929
# 2                        7.793
# 3                        6.007
# 4                        8.800

# %%
lad_df.to_csv('../data/comparison/comparison_eng_LAD_deprivation_2019.csv.gz', compression='gzip')
lad_df.to_csv('../data/comparison/comparison_eng_LAD_deprivation_2019.csv')

# %% [markdown]
# ## Import Postcode related files for creating lookups
# * Source - [PostCode to ward and LAD lookup](https://ons.maps.arcgis.com/home/item.html?id=c4aeb11ff5b045018b7340e807d645cb)
# * Source - [PostCode to Output Areas lookup](http://geoportal1-ons.opendata.arcgis.com/datasets/80628f9289574ba4b39a76ca7830b7e9_0)
# * Source - [Output Area to Ward to Local Authority District (December 2017) Lookup in England and Wales](https://geoportal.statistics.gov.uk/datasets/988e581ac9d942dfa6d642c4e98b048c_0)

# %%
postcode_df = pd.read_csv('../data/geo/pcd11_par11_wd11_lad11_ew_lu.csv',encoding='iso-8859-1')

postcode_to_oa_df = pd.read_csv('../data/geo/Postcode_to_Output_Area_to_Lower_Layer_Super_Output_Area_to_Middle_Layer_Super_Output_Area_to_Local_Authority_District_February_2018_Lookup_in_the_UK.csv',encoding='iso-8859-1')

oa_to_ward_2017 = pd.read_csv('../data/geo/Output_Area_to_Ward_to_Local_Authority_District_December_2017_Lookup_in_England_and_Wales.csv',encoding='iso-8859-1')
# Out:
# c:\users\drkan\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# c:\users\drkan\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
postcode_df.head()
# Out:
#       pcd7      pcd8     pcds par11cd par11nm par11nmw     wd11cd      wd11nm  \
# 0  AL1 1AG  AL1  1AG  AL1 1AG     NaN     NaN      NaN  E05004802     Sopwell
# 1  AL1 1AJ  AL1  1AJ  AL1 1AJ     NaN     NaN      NaN  E05004802     Sopwell
# 2  AL1 1AR  AL1  1AR  AL1 1AR     NaN     NaN      NaN  E05004789  Cunningham
# 3  AL1 1AS  AL1  1AS  AL1 1AS     NaN     NaN      NaN  E05004799   St Peters
# 4  AL1 1BH  AL1  1BH  AL1 1BH     NaN     NaN      NaN  E05004802     Sopwell
#
#   wd11nmw    lad11cd    lad11nm lad11nmw
# 0     NaN  E07000100  St Albans      NaN
# 1     NaN  E07000100  St Albans      NaN
# 2     NaN  E07000100  St Albans      NaN
# 3     NaN  E07000100  St Albans      NaN
# 4     NaN  E07000100  St Albans      NaN

# %%
postcode_to_oa_df.head()
# Out:
#       pcd7      pcd8     pcds  dointr  doterm  usertype       oa11   lsoa11cd  \
# 0  AB1 1EZ  AB1  1EZ  AB1 1EZ  198001  199606         0  S00090528  S01006645
# 1  AB1 0AA  AB1  0AA  AB1 0AA  198001  199606         0  S00090303  S01006514
# 2  AB1 0RE  AB1  0RE  AB1 0RE  198001  199606         0  S00090294  S01006507
# 3  AB1 1FA  AB1  1FA  AB1 1FA  198001  199606         0  S00090532  S01006645
# 4  AB1 0RF  AB1  0RF  AB1 0RF  199210  199606         0  S00090296  S01006507
#
#     msoa11cd      ladcd                                   lsoa11nm  \
# 0  S02001261  S12000033                         George Street - 01
# 1  S02001237  S12000033  Cults, Bieldside and Milltimber West - 02
# 2  S02001236  S12000033                                Culter - 02
# 3  S02001261  S12000033                         George Street - 01
# 4  S02001236  S12000033                                Culter - 02
#
#                                msoa11nm          ladnm ladnmw  FID
# 0                         George Street  Aberdeen City    NaN    1
# 1  Cults, Bieldside and Milltimber West  Aberdeen City    NaN    2
# 2                                Culter  Aberdeen City    NaN    3
# 3                         George Street  Aberdeen City    NaN    4
# 4                                Culter  Aberdeen City    NaN    5

# %%
oa_to_ward_2017.head()
# Out:
#       OA11CD     WD17CD  WD17NM WD17NMW    LAD17CD     LAD17NM    FID
# 0  E00069981  E05001828  Bridge     NaN  E06000018  Nottingham  10001
# 1  E00069980  E05001828  Bridge     NaN  E06000018  Nottingham  10002
# 2  E00069988  E05001828  Bridge     NaN  E06000018  Nottingham  10003
# 3  E00173541  E05001828  Bridge     NaN  E06000018  Nottingham  10004
# 4  E00173506  E05001828  Bridge     NaN  E06000018  Nottingham  10005

# %%
postcode_to_ward2017_df_merged = pd.merge(postcode_to_oa_df, oa_to_ward_2017, left_on='oa11', right_on='OA11CD',sort=True)

# %%
postcode_to_ward2017_df_merged = postcode_to_ward2017_df_merged[['pcd7','pcd8','WD17CD','WD17NM','ladcd','ladnm']]
postcode_to_ward2017_df_merged.head()
# Out:
#       pcd7      pcd8     WD17CD      WD17NM      ladcd           ladnm
# 0  EC2Y8NJ  EC2Y 8NJ  E05009288  Aldersgate  E09000001  City of London
# 1  EC2Y8DR  EC2Y 8DR  E05009288  Aldersgate  E09000001  City of London
# 2  EC2Y8PE  EC2Y 8PE  E05009288  Aldersgate  E09000001  City of London
# 3  EC2Y8BY  EC2Y 8BY  E05009288  Aldersgate  E09000001  City of London
# 4  EC2Y8DP  EC2Y 8DP  E05009288  Aldersgate  E09000001  City of London

# %%
postcode_df = postcode_df[['pcd7','pcd8','wd11cd','wd11nm','lad11cd','lad11nm']]
postcode_df.head()
# Out:
#       pcd7      pcd8     wd11cd      wd11nm    lad11cd    lad11nm
# 0  AL1 1AG  AL1  1AG  E05004802     Sopwell  E07000100  St Albans
# 1  AL1 1AJ  AL1  1AJ  E05004802     Sopwell  E07000100  St Albans
# 2  AL1 1AR  AL1  1AR  E05004789  Cunningham  E07000100  St Albans
# 3  AL1 1AS  AL1  1AS  E05004799   St Peters  E07000100  St Albans
# 4  AL1 1BH  AL1  1BH  E05004802     Sopwell  E07000100  St Albans

# %%
postcode_df.describe()
# Out:
#            pcd7      pcd8     wd11cd   wd11nm    lad11cd   lad11nm
# count   1308780   1308780    1308780  1308780    1308780   1308780
# unique  1308780   1308780       8573     7815        348       348
# top     DN3 2LB  PL21 0JR  E05000649   Castle  E06000052  Cornwall
# freq          1         1       1405     4436      18543     18543

# %%
postcode_to_ward17_to_lad11_lookup = pd.merge(postcode_to_ward2017_df_merged, postcode_df, \
                                              left_on='pcd8', right_on='pcd8',sort=True)

# %%
aggregagations = {'pcd8': 'count'}

ward17_to_lad11_lookup =  pd.pivot_table(postcode_to_ward17_to_lad11_lookup, index=['WD17CD','lad11cd'],\
                                         aggfunc = aggregagations)
ward17_to_lad11_lookup.reset_index(inplace=True)

# %%
ward17_to_lad11_lookup.head()
# Out:
#       WD17CD    lad11cd  pcd8
# 0  E05000026  E09000002   158
# 1  E05000027  E09000002   136
# 2  E05000028  E09000002   157
# 3  E05000029  E09000002   170
# 4  E05000030  E09000002   145

# %% [markdown]
# ### Create lookups between LAD2011 and LAD2017 codes
#
# Deprivation data uses LAD2013, which is the same as LAD2017 but different from LAD2011

# %%
lad17_df = pd.DataFrame.pivot_table(oa_to_ward_2017, columns=['LAD17CD','LAD17NM'],
                      aggfunc='count', fill_value=None, margins=False,
                      dropna=True, margins_name='All')['OA11CD'].reset_index()

lad11_df = pd.DataFrame.pivot_table(postcode_df, columns=['lad11cd','lad11nm'],
                      aggfunc='count', fill_value=None, margins=False,
                      dropna=True, margins_name='All')['pcd8'].reset_index()

lad17_to_lad11_lookup = pd.merge(lad11_df, lad17_df, left_on='lad11nm', right_on='LAD17NM',sort=True)

# %%
lad17_to_lad11_lookup.head()
# Out:
#      lad11cd       lad11nm   0_x    LAD17CD       LAD17NM  0_y
# 0  E07000223          Adur  1297  E07000223          Adur  211
# 1  E07000026     Allerdale  3606  E07000026     Allerdale  320
# 2  E07000032  Amber Valley  2378  E07000032  Amber Valley  400
# 3  E07000224          Arun  4360  E07000224          Arun  519
# 4  E07000170      Ashfield  2344  E07000170      Ashfield  385

# %% [markdown]
# ---
#
# ## Import Charities Data: Postcode Level
#
# * Source - [CharityBase](https://charitybase.uk/)

# %% [markdown]
# ### Now that we have prepared all the lookup data, we can load up the charities data

# %%
cb_df = pd.read_csv('../data/comparison/charity-base-1548222944.csv',encoding='iso-8859-1')

# %%
cb_df.head(3)
# Out:
#                           name  ids.GB-CHC  \
# 0          The British Council      209131
# 1              Nuffield Health      205533
# 2  Lloyd'S Register Foundation     1145988
#
#                                      contact.address  \
# 0  ["The British Council","10 Spring Gardens","Lo...
# 1  ["Nuffield Health","Epsom Gateway","2 Ashley A...
# 2                   ["71 Fenchurch Street","London"]
#
#                     contact.email  contact.geo.latitude  \
# 0     trustees@britishcouncil.org             51.506999
# 1  toby.newman@nuffieldhealth.com             51.331616
# 2          michelle.davies@lr.org             51.512507
#
#    contact.geo.longitude    contact.person  contact.phone contact.postcode
# 0              -0.129744  Ms Alison Coutts            NaN         SW1A 2BN
# 1              -0.270322    Mr Toby Newman    01372426885         KT18 5AL
# 2              -0.078733   Michelle Davies  0207 423 2783         EC3M 4BS

# %%
cb_df_merged = pd.merge(cb_df, postcode_to_ward2017_df_merged, left_on='contact.postcode', right_on='pcd7',sort=True)

# %%
cb_df_merged.head()
# Out:
#                                         name  ids.GB-CHC  \
# 0            St Albans Cathedral Music Trust     1051072
# 1             The St. Albans Cathedral Trust     1037405
# 2            Friends Of The Abbey Jmi School      802214
# 3  The Mothers' Union (Diocese Of St Albans)      249814
# 4    The St Albans Diocesan Board Of Finance      248887
#
#                                      contact.address  \
# 0  ["St Albans Cathedral","Sumpter Yard","St. Alb...
# 1  ["St Albans Cathedral","Sumpter Yard","St. Alb...
# 2  ["The Abbey Ce Va Primary School","Grove Road"...
# 3  ["The Mothers Union","41 Holywell Hill","St. A...
# 4  ["Holywell Lodge","41 Holywell Hill","St Albans"]
#
#                    contact.email  contact.geo.latitude  contact.geo.longitude  \
# 0      ado@stalbanscathedral.org             51.749861              -0.341570
# 1  finance@stalbanscathedral.org             51.749861              -0.341570
# 2     friends@abbey.herts.sch.uk             51.747408              -0.342340
# 3  sec_mustalbans@btinternet.com             51.748858              -0.340787
# 4     mail@stalbans.anglican.org             51.748858              -0.340787
#
#                             contact.person   contact.phone contact.postcode  \
# 0                       Mr Timothy Fleming             NaN          AL1 1BY
# 1                       Mr Timothy Fleming             NaN          AL1 1BY
# 2                                Emma Fenn    01727 851802          AL1 1DQ
# 3                            Mrs Liz James    01727 858979          AL1 1HD
# 4  The St Albans Diocesan Board Of Finance  (01727) 854532          AL1 1HE
#
#       pcd7      pcd8     WD17CD     WD17NM      ladcd      ladnm
# 0  AL1 1BY  AL1  1BY  E05004803    Verulam  E07000240  St Albans
# 1  AL1 1BY  AL1  1BY  E05004803    Verulam  E07000240  St Albans
# 2  AL1 1DQ  AL1  1DQ  E05004803    Verulam  E07000240  St Albans
# 3  AL1 1HD  AL1  1HD  E05004799  St Peters  E07000240  St Albans
# 4  AL1 1HE  AL1  1HE  E05004799  St Peters  E07000240  St Albans

# %%
cb_df_merged = pd.merge(cb_df_merged, lad17_to_lad11_lookup, left_on='ladcd', right_on='LAD17CD',sort=True)

# %%
cb_df_merged.head()
# Out:
#                                  name  ids.GB-CHC  \
# 0               The Kilimatinde Trust     1063397
# 1                       Miles For Men     1154996
# 2  Catcote School Parents And Friends     1054871
# 3        Friends Of Teesside Archives     1082369
# 4               Platform Arts Limited     1119710
#
#                                      contact.address  \
# 0                   ["108 High Street","Hartlepool"]
# 1              ["Flat 13","Innes Road","Hartlepool"]
# 2     ["Catcote School","Catcote Road","Hartlepool"]
# 3  ["The Treasurer","Friends Of Teesside Archives...
# 4  ["Platform Arts Ltd","Middlesbrough Railway St...
#
#                                 contact.email  contact.geo.latitude  \
# 0                            ktrust97@aol.com             54.695037
# 1                  hartlepool@milesformen.com             54.656487
# 2                                         NaN             54.677558
# 3  enquiries@friendsofteessidearchives.org.uk             54.578293
# 4                       info@platformarts.net             54.578944
#
#    contact.geo.longitude         contact.person contact.phone  \
# 0              -1.182314  The Kilimatinde Trust   07790110086
# 1              -1.234086         Mr Michael Day   07479934400
# 2              -1.236295          Caroline Lamb   01429264036
# 3              -1.232241    Mr Andrew Bousfield  01642 557439
# 4              -1.234921     Mrs Lorraine Brown   01642248330
#
#   contact.postcode     pcd7      pcd8     WD17CD                WD17NM  \
# 0          TS240QY  TS240QY  TS24 0QY  E05008947  Headland and Harbour
# 1          TS253HQ  TS253HQ  TS25 3HQ  E05008949           Manor House
# 2          TS254EZ  TS254EZ  TS25 4EZ  E05008950            Rural West
# 3          TS1 1DB  TS1 1DB  TS1  1DB  E05009857               Central
# 4          TS1 1EG  TS1 1EG  TS1  1EG  E05009857               Central
#
#        ladcd          ladnm    lad11cd        lad11nm   0_x    LAD17CD  \
# 0  E06000001     Hartlepool  E06000001     Hartlepool  2277  E06000001
# 1  E06000001     Hartlepool  E06000001     Hartlepool  2277  E06000001
# 2  E06000001     Hartlepool  E06000001     Hartlepool  2277  E06000001
# 3  E06000002  Middlesbrough  E06000002  Middlesbrough  3193  E06000002
# 4  E06000002  Middlesbrough  E06000002  Middlesbrough  3193  E06000002
#
#          LAD17NM  0_y
# 0     Hartlepool  313
# 1     Hartlepool  313
# 2     Hartlepool  313
# 3  Middlesbrough  442
# 4  Middlesbrough  442

# %%
cb_df_merged.count()
# Out:
# name                     80872
# ids.GB-CHC               80872
# contact.address          80872
# contact.email            62912
# contact.geo.latitude     80872
# contact.geo.longitude    80872
# contact.person           80872
# contact.phone            70481
# contact.postcode         80872
# pcd7                     80872
# pcd8                     80872
# WD17CD                   80872
# WD17NM                   80872
# ladcd                    80872
# ladnm                    80872
# lad11cd                  80872
# lad11nm                  80872
# 0_x                      80872
# LAD17CD                  80872
# LAD17NM                  80872
# 0_y                      80872
# dtype: int64

# %%
cb_df_merged[cb_df_merged['ladnm'] == 'St Albans']
# Out:
#                                                     name  ids.GB-CHC  \
# 47104                    St Albans Cathedral Music Trust     1051072
# 47105                     The St. Albans Cathedral Trust     1037405
# 47106                    Friends Of The Abbey Jmi School      802214
# 47107          The Mothers' Union (Diocese Of St Albans)      249814
# 47108            The St Albans Diocesan Board Of Finance      248887
# 47109                 Ecumenical Partnership Initiatives     1132125
# 47110                          Bishops College, Cheshunt      311097
# 47111  Bromham Church Of England School Educational Fund     1053894
# 47112                        Archdeacon Burney'S Charity      263606
# 47113    Ampthill And Meppershall Educational Foundation      307472
# 47114  The Hertfordshire And Bedfordshire Clergy Charity      248889
# 47115  Chipperfield Church Of England Primary School ...      311007
# 47116                             Mary Elena Smith Trust      312152
# 47117     Tring Church Of England Schools Education Fund     1074774
# 47118                             The John Gates Charity      206208
# 47119                Harold Browne And Higgin Prize Fund      311017
# 47120                   Abbots Langley War Memorial Fund      210048
# 47121                     Dixon'S Educational Foundation      310997
# 47122      Tewin Cowper Endowed Church Of England School      310981
# 47123         St Peter'S School Parent Staff Association     1139130
# 47124  Rickmansworth And Chorleywood District Scout C...      302566
# 47125  7Th Rickmansworth And Chorleywood (1St Maple C...      274415
# 47126                       St Albans School Association     1079376
# 47127  The Parochial Church Council Of The Ecclesiast...     1132924
# 47128                        Rendcomb College Foundation      311713
# 47129                    The Williams Church Music Trust      311088
# 47130                    The Sybil Owen Charitable Trust     1106153
# 47131                          The James Weir Foundation      251764
# 47132                                      M And C Trust      265391
# 47133                               G4S Employees' Trust      281616
# ...                                                  ...         ...
# 47625                                               Opda     1179697
# 47626  Harpenden And Wheathampstead District Scout Co...      302531
# 47627                    St Albans And District Foodbank     1158917
# 47628                      Harpenden Spotlight On Africa     1117585
# 47629                          Times Amateur Boxing Club     1132776
# 47630            The Jarvis (Harpenden) Charitable Trust      287659
# 47631                                Leaside Womens Club     1034712
# 47632                                Kimpton Folk Events     1168562
# 47633                        The Friends Of High Beeches      297518
# 47634                     Friends Of Sauncey Wood School      290481
# 47635                    Friends Of St. Luke'S, Redbourn     1106427
# 47636                      Harpenden Money Advice Centre     1161164
# 47637                 Bethany Community Church Harpenden     1176089
# 47638  The Parochial Church Council Of The Ecclesiast...     1131603
# 47639                       Friends Of Harpenden Academy     1159562
# 47640                The Music Makers Choir Of Harpenden     1120211
# 47641                                Baroque At The Edge     1175166
# 47642              Watling View Parent Staff Association     1158303
# 47643  St George'S School Association Of Parents And ...     1150723
# 47644               Crabtree School Parents' Association      297330
# 47645            Timeout After School And Breakfast Club     1172436
# 47646  Parochial Church Council Of St Nicholas, Harpe...     1130793
# 47647             The Joseph And Lilian Sully Foundation     1014823
# 47648                              Grosvenor Womens Club     1024452
# 47649             10Th Harpenden (Methodist) Scout Group      292736
# 47650                              Crabtree Church Trust     1092748
# 47651                                  Harpenden Society      278154
# 47652                          5Th Harpenden Scout Group     1155533
# 47653                                Crossroads Retreats     1118176
# 47654                    St Albans Rangers Football Club     1130881
#
#                                          contact.address  \
# 47104  ["St Albans Cathedral","Sumpter Yard","St. Alb...
# 47105  ["St Albans Cathedral","Sumpter Yard","St. Alb...
# 47106  ["The Abbey Ce Va Primary School","Grove Road"...
# 47107  ["The Mothers Union","41 Holywell Hill","St. A...
# 47108  ["Holywell Lodge","41 Holywell Hill","St Albans"]
# 47109  ["St. Albans Diocesan Office","41 Holywell Hil...
# 47110  ["Holywell Lodge","41 Holywell Hill","St Albans"]
# 47111                   ["41 Holywell Hill","St Albans"]
# 47112  ["Holywell Lodge","41 Holywell Hill","St. Alba...
# 47113  ["Holywell Lodge","41 Holywell Hill","St Alban...
# 47114                   ["41 Holywell Hill","St Albans"]
# 47115  ["Holywell Lodge","41 Holywell Hill","St Alban...
# 47116  ["Holywell Lodge","41 Holywell Hill","St. Alba...
# 47117  ["Holywell Lodge","41 Holywell Hill","St Albans"]
# 47118  ["Holywell Lodge","41 Holywell Hill","St Alban...
# 47119  ["Holywell Lodge","41 Holywell Hill","St Alban...
# 47120  ["Holywell Lodge","41 Holywell Hill","St. Alba...
# 47121  ["Holywell Lodge","41 Holywell Hill","St Alban...
# 47122  ["Holywell Lodge","41 Holywell Hill","St Alban...
# 47123  ["St. Peters Jmi School","Cottonmill Lane","St...
# 47124        ["2 Pine Ridge","London Road","St. Albans"]
# 47125        ["2 Pine Ridge","London Road","St. Albans"]
# 47126              ["18 Cunningham Avenue","St. Albans"]
# 47127                  ["2 Hordle Gardens","St. Albans"]
# 47128  ["Strutt & Parker","15 London Road","St. Albans"]
# 47129  ["Pendragon House","65 London Road","St Albans...
# 47130  ["Photiades Solicitors","36-38 London Road","S...
# 47131  ["Gloucester House","72 London Road","St Alban...
# 47132    ["Mercer & Hole","72 London Road","St. Albans"]
# 47133    ["Mercer & Hole","72 London Road","St. Albans"]
# ...                                                  ...
# 47625       ["6 The Mews","Breadcroft Lane","Harpenden"]
# 47626                    ["5 Browning Road","Harpenden"]
# 47627                    ["5 Browning Road","Harpenden"]
# 47628                   ["102 Station Road","Harpenden"]
# 47629    ["15 Robin Court","Westfield Road","Harpenden"]
# 47630  ["1 Waterside","Station Road","Harpenden","Her...
# 47631               ["101 Lower Luton Road","Harpenden"]
# 47632     ["Raisins Cottage","Mackerye End","Harpenden"]
# 47633     ["Dane Spring","Bower Heath Lane","Harpenden"]
# 47634  ["Sauncey Wood School","Pickford Hill","Harpen...
# 47635                    ["45 Porters Hill","Harpenden"]
# 47636                    ["2 Turners Close","Harpenden"]
# 47637                    ["2 Turners Close","Harpenden"]
# 47638         ["3 Avon Court","Milton Road","Harpenden"]
# 47639  ["1 Haddon Court","Shakespeare Road","Harpenden"]
# 47640                    ["112 Cowper Road","Harpenden"]
# 47641                  ["70 Overstone Road","Harpenden"]
# 47642                ["17 Carisbrooke Road","Harpenden"]
# 47643                 ["19 Lyndhurst Drive","Harpenden"]
# 47644  ["Crabtree School","Crabtree Lane","Harpenden"...
# 47645                  ["153 Crabtree Lane","Harpenden"]
# 47646                   ["92 Crabtree Lane","Harpenden"]
# 47647                   ["92 Crabtree Lane","Harpenden"]
# 47648            ["72 Aldwickbury Crescent","Harpenden"]
# 47649  ["Crabtree Fields","Waldegrave Park","Harpende...
# 47650               ["91 Chesterton Avenue","Harpenden"]
# 47651                   ["71 Alzey Gardens","Harpenden"]
# 47652                     ["54 Meadow Walk","Harpenden"]
# 47653                 ["Po Box 522","Harpenden","Herts"]
# 47654  ["Harperbury Hospital","Harper Lane","Shenley"...
#
#                                   contact.email  contact.geo.latitude  \
# 47104                 ado@stalbanscathedral.org             51.749861
# 47105             finance@stalbanscathedral.org             51.749861
# 47106                friends@abbey.herts.sch.uk             51.747408
# 47107             sec_mustalbans@btinternet.com             51.748858
# 47108                mail@stalbans.anglican.org             51.748858
# 47109             admin@workplacematters.org.uk             51.748858
# 47110                                       NaN             51.748858
# 47111                 e.jones142@btinternet.com             51.748858
# 47112                                       NaN             51.748858
# 47113                                       NaN             51.748858
# 47114                mail@stalbans.anglican.org             51.748858
# 47115                                       NaN             51.748858
# 47116                                       NaN             51.748858
# 47117                                       NaN             51.748858
# 47118                                       NaN             51.748858
# 47119                                       NaN             51.748858
# 47120                                       NaN             51.748858
# 47121                                       NaN             51.748858
# 47122                                       NaN             51.748858
# 47123               admin@stpeters.herts.sch.uk             51.746752
# 47124                     martinlantree@aol.com             51.738257
# 47125                                       NaN             51.738257
# 47126                       sasa@sasgateway.com             51.744597
# 47127                        office@sth-stp.org             51.745224
# 47128       patrick.beddows@struttandparker.com             51.750655
# 47129            richard.lovett@gilberts.uk.com             51.749541
# 47130               davidshiebert@photiades.com             51.750305
# 47131                                       NaN             51.749895
# 47132               helenprice@mercerhole.co.uk             51.749895
# 47133                                       NaN             51.749895
# ...                                         ...                   ...
# 47625                                       NaN             51.816760
# 47626              dc-harpenden@virginmedia.com             51.819147
# 47627  manager@stalbansdistrict.foodbank.org.uk             51.819147
# 47628                     enquiries@hsoa.org.uk             51.818693
# 47629                      mail@timesabc.org.uk             51.828619
# 47630                                       NaN             51.825029
# 47631                 graham.andee@ntlworld.com             51.824834
# 47632                      hello@kimptonfolk.uk             51.832696
# 47633            admin@highbeeches.herts.sch.uk             51.842027
# 47634            sauncey.wood.friends@gmail.com             51.827522
# 47635                foslr@stlukes.herts.sch.uk             51.828014
# 47636     info@harpendenmoneyadvicecentre.co.uk             51.829299
# 47637                    admin@bethanycc.org.uk             51.829299
# 47638     parish.office@stjohnsharpenden.org.uk             51.813319
# 47639          contact.foha.harpenden@gmail.com             51.814655
# 47640                                       NaN             51.814442
# 47641               info@baroqueattheedge.co.uk             51.816373
# 47642                lucy.rayner@btinternet.com             51.819588
# 47643                psa@stgeorges.herts.sch.uk             51.818494
# 47644             admin@crabtreejm.herts.sch.uk             51.818263
# 47645                                       NaN             51.818263
# 47646         office@stnicholasharpenden.org.uk             51.816757
# 47647                ptimms@kingstonsmith.co.uk             51.816757
# 47648                  avis.dalton@ntlworld.com             51.814226
# 47649          gsl@10th-harpenden-scouts.org.uk             51.814125
# 47650               johncrablower@hotmail.co.uk             51.813517
# 47651            secretary@harpendensociety.org             51.812180
# 47652            exec@5thharpendenscouts.org.uk             51.809990
# 47653             info@crossroadsretreats.co.uk             51.747650
# 47654                    lisarees17@outlook.com             51.703907
#
#        contact.geo.longitude                           contact.person  \
# 47104              -0.341570                       Mr Timothy Fleming
# 47105              -0.341570                       Mr Timothy Fleming
# 47106              -0.342340                                Emma Fenn
# 47107              -0.340787                            Mrs Liz James
# 47108              -0.340787  The St Albans Diocesan Board Of Finance
# 47109              -0.340787                Mrs Clara Lawrence-Bailey
# 47110              -0.340787  The St Albans Diocesan Board Of Finance
# 47111              -0.340787      St Albans Diocesan Board Of Finance
# 47112              -0.340787                          Mr Nigel Benger
# 47113              -0.340787  The St Albans Diocesan Board Of Finance
# 47114              -0.340787      St Albans Diocesan Board Of Finance
# 47115              -0.340787  The St Albans Diocesan Board Of Finance
# 47116              -0.340787  The St Albans Diocesan Board Of Finance
# 47117              -0.340787  The St Albans Diocesan Board Of Finance
# 47118              -0.340787  The St Albans Diocesan Board Of Finance
# 47119              -0.340787  The St Albans Diocesan Board Of Finance
# 47120              -0.340787  The St Albans Diocesan Board Of Finance
# 47121              -0.340787  The St Albans Diocesan Board Of Finance
# 47122              -0.340787  The St Albans Diocesan Board Of Finance
# 47123              -0.335382                      Mrs Vitina Thwaites
# 47124              -0.315360                        Mr Martin Lantree
# 47125              -0.315360                        Mr Martin Lantree
# 47126              -0.322917             St Albans School Association
# 47127              -0.324261                        Mr Stephen Wilson
# 47128              -0.337919                       Mr Patrick Beddows
# 47129              -0.334431                               R A Lovett
# 47130              -0.337975                        Mr David Shiebert
# 47131              -0.336339               Mercer & Hole Trustees Ltd
# 47132              -0.336339            Ms Helen Claire Barbara Price
# 47133              -0.336339                             The Director
# ...                      ...                                      ...
# 47625              -0.351099                        Mr Daniel Keating
# 47626              -0.346891                       Mr John Mulholland
# 47627              -0.346891                          John Mulholland
# 47628              -0.346603                         Caroline Swanson
# 47629              -0.352305                             Brian Deegan
# 47630              -0.342525                         Mr Brian Curragh
# 47631              -0.341444                         Mrs Andrea Major
# 47632              -0.320232                          Richard Stewart
# 47633              -0.335790                      Miss Lisa Jane Kiff
# 47634              -0.336977          Friends Of Sauncey Wood Primary
# 47635              -0.339310                              Roz Girling
# 47636              -0.342427                         Mr Richard Payne
# 47637              -0.342427                         Mr Richard Payne
# 47638              -0.348758                   Mr Paul Ashley Bedding
# 47639              -0.347974                            Mrs Jo Harman
# 47640              -0.345511                 Mr Patrick Angus Stevens
# 47641              -0.345948                         Mrs Lucy Bending
# 47642              -0.341173                              Lucy Rayner
# 47643              -0.342083                             Eddy De Jong
# 47644              -0.337783             Treasurer To The Association
# 47645              -0.337783                          Mrs Sarah Beale
# 47646              -0.338781                           Mr Peter Timms
# 47647              -0.338781                      Mr Peter John Timms
# 47648              -0.339063                          Mrs Avis Dalton
# 47649              -0.334511   10Th Harpenden (Methodist) Scout Group
# 47650              -0.340438                     Mr John Arthur Lower
# 47651              -0.338137                          Robert Fletcher
# 47652              -0.346051                         Mrs Rachel Jones
# 47653              -0.301973                        Mr Chris Blakeley
# 47654              -0.304045                        St Albans Rangers
#
#         contact.phone contact.postcode     pcd7      pcd8     WD17CD  \
# 47104             NaN          AL1 1BY  AL1 1BY  AL1  1BY  E05004803
# 47105             NaN          AL1 1BY  AL1 1BY  AL1  1BY  E05004803
# 47106    01727 851802          AL1 1DQ  AL1 1DQ  AL1  1DQ  E05004803
# 47107    01727 858979          AL1 1HD  AL1 1HD  AL1  1HD  E05004799
# 47108  (01727) 854532          AL1 1HE  AL1 1HE  AL1  1HE  E05004799
# 47109   01727 818 144          AL1 1HE  AL1 1HE  AL1  1HE  E05004799
# 47110  (01727) 854532          AL1 1HE  AL1 1HE  AL1  1HE  E05004799
# 47111  (01727) 854532          AL1 1HE  AL1 1HE  AL1  1HE  E05004799
# 47112     01727854532          AL1 1HE  AL1 1HE  AL1  1HE  E05004799
# 47113    01727 854532          AL1 1HE  AL1 1HE  AL1  1HE  E05004799
# 47114  (01727) 854532          AL1 1HE  AL1 1HE  AL1  1HE  E05004799
# 47115    01727 854532          AL1 1HE  AL1 1HE  AL1  1HE  E05004799
# 47116    01727 854532          AL1 1HE  AL1 1HE  AL1  1HE  E05004799
# 47117    01727 854532          AL1 1HE  AL1 1HE  AL1  1HE  E05004799
# 47118    01727 854532          AL1 1HE  AL1 1HE  AL1  1HE  E05004799
# 47119    01727 854532          AL1 1HE  AL1 1HE  AL1  1HE  E05004799
# 47120    01727 854532          AL1 1HE  AL1 1HE  AL1  1HE  E05004799
# 47121    01727 854532          AL1 1HE  AL1 1HE  AL1  1HE  E05004799
# 47122    01727 854532          AL1 1HE  AL1 1HE  AL1  1HE  E05004799
# 47123    01727 853075          AL1 1HL  AL1 1HL  AL1  1HL  E05004802
# 47124     01727862602          AL1 1JE  AL1 1JE  AL1  1JE  E05004789
# 47125     01727862602          AL1 1JE  AL1 1JE  AL1  1JE  E05004789
# 47126    01727 842193          AL1 1JL  AL1 1JL  AL1  1JL  E05004789
# 47127     01727863490          AL1 1JW  AL1 1JW  AL1  1JW  E05004789
# 47128    01727 738284          AL1 1LA  AL1 1LA  AL1  1LA  E05004799
# 47129    01727 750000          AL1 1LJ  AL1 1LJ  AL1  1LJ  E05004799
# 47130    01727 833134          AL1 1NG  AL1 1NG  AL1  1NG  E05004799
# 47131    01727 869141          AL1 1NS  AL1 1NS  AL1  1NS  E05004799
# 47132    01727 869141          AL1 1NS  AL1 1NS  AL1  1NS  E05004799
# 47133    01727 869141          AL1 1NS  AL1 1NS  AL1  1NS  E05004799
# ...               ...              ...      ...       ...        ...
# 47625    07788 740472          AL5 4TF  AL5 4TF  AL5  4TF  E05004790
# 47626    01582 767878          AL5 4TS  AL5 4TS  AL5  4TS  E05004790
# 47627     01582767878          AL5 4TS  AL5 4TS  AL5  4TS  E05004790
# 47628     07768465640          AL5 4TU  AL5 4TU  AL5  4TU  E05004790
# 47629   01582 621 676          AL5 4UH  AL5 4UH  AL5  4UH  E05004791
# 47630    01582 711761          AL5 4US  AL5 4US  AL5  4US  E05004791
# 47631             NaN          AL5 5AL  AL5 5AL  AL5  5AL  E05004790
# 47632     01582462098          AL5 5DU  AL5 5DU  AL5  5DU  E05004804
# 47633     01582761901          AL5 5EB  AL5 5EB  AL5  5EB  E05004804
# 47634    01582 621514          AL5 5HL  AL5 5HL  AL5  5HL  E05004790
# 47635    01582 765043          AL5 5HR  AL5 5HR  AL5  5HR  E05004790
# 47636     01582621998          AL5 5HY  AL5 5HY  AL5  5HY  E05004790
# 47637             NaN          AL5 5HY  AL5 5HY  AL5  5HY  E05004790
# 47638    01582 763381          AL5 5LN  AL5 5LN  AL5  5LN  E05004793
# 47639     07725759460          AL5 5NB  AL5 5NB  AL5  5NB  E05004793
# 47640             NaN          AL5 5NL  AL5 5NL  AL5  5NL  E05004793
# 47641    01582 763494          AL5 5PJ  AL5 5PJ  AL5  5PJ  E05004793
# 47642    07811 186814          AL5 5QS  AL5 5QS  AL5  5QS  E05004790
# 47643             NaN          AL5 5QW  AL5 5QW  AL5  5QW  E05004790
# 47644     01582623501          AL5 5RD  AL5 5RD  AL5  5RD  E05004790
# 47645    01582 713452          AL5 5RD  AL5 5RD  AL5  5RD  E05004790
# 47646    01582 760752          AL5 5RW  AL5 5RW  AL5  5RW  E05004790
# 47647    01582 760752          AL5 5RW  AL5 5RW  AL5  5RW  E05004790
# 47648    01582 623951          AL5 5SE  AL5 5SE  AL5  5SE  E05004790
# 47649             NaN          AL5 5SF  AL5 5SF  AL5  5SF  E05004790
# 47650    01582 712428          AL5 5ST  AL5 5ST  AL5  5ST  E05004790
# 47651    01582 763036          AL5 5SY  AL5 5SY  AL5  5SY  E05004790
# 47652    01582 763613          AL5 5TG  AL5 5TG  AL5  5TG  E05004793
# 47653     07964379234          AL5 9EW  AL5 9EW  AL5  9EW  E05004785
# 47654             NaN          WD7 9HQ  WD7 9HQ  WD7  9HQ  E05004797
#
#                 WD17NM      ladcd      ladnm    lad11cd    lad11nm   0_x  \
# 47104          Verulam  E07000240  St Albans  E07000100  St Albans  3901
# 47105          Verulam  E07000240  St Albans  E07000100  St Albans  3901
# 47106          Verulam  E07000240  St Albans  E07000100  St Albans  3901
# 47107        St Peters  E07000240  St Albans  E07000100  St Albans  3901
# 47108        St Peters  E07000240  St Albans  E07000100  St Albans  3901
# 47109        St Peters  E07000240  St Albans  E07000100  St Albans  3901
# 47110        St Peters  E07000240  St Albans  E07000100  St Albans  3901
# 47111        St Peters  E07000240  St Albans  E07000100  St Albans  3901
# 47112        St Peters  E07000240  St Albans  E07000100  St Albans  3901
# 47113        St Peters  E07000240  St Albans  E07000100  St Albans  3901
# 47114        St Peters  E07000240  St Albans  E07000100  St Albans  3901
# 47115        St Peters  E07000240  St Albans  E07000100  St Albans  3901
# 47116        St Peters  E07000240  St Albans  E07000100  St Albans  3901
# 47117        St Peters  E07000240  St Albans  E07000100  St Albans  3901
# 47118        St Peters  E07000240  St Albans  E07000100  St Albans  3901
# 47119        St Peters  E07000240  St Albans  E07000100  St Albans  3901
# 47120        St Peters  E07000240  St Albans  E07000100  St Albans  3901
# 47121        St Peters  E07000240  St Albans  E07000100  St Albans  3901
# 47122        St Peters  E07000240  St Albans  E07000100  St Albans  3901
# 47123          Sopwell  E07000240  St Albans  E07000100  St Albans  3901
# 47124       Cunningham  E07000240  St Albans  E07000100  St Albans  3901
# 47125       Cunningham  E07000240  St Albans  E07000100  St Albans  3901
# 47126       Cunningham  E07000240  St Albans  E07000100  St Albans  3901
# 47127       Cunningham  E07000240  St Albans  E07000100  St Albans  3901
# 47128        St Peters  E07000240  St Albans  E07000100  St Albans  3901
# 47129        St Peters  E07000240  St Albans  E07000100  St Albans  3901
# 47130        St Peters  E07000240  St Albans  E07000100  St Albans  3901
# 47131        St Peters  E07000240  St Albans  E07000100  St Albans  3901
# 47132        St Peters  E07000240  St Albans  E07000100  St Albans  3901
# 47133        St Peters  E07000240  St Albans  E07000100  St Albans  3901
# ...                ...        ...        ...        ...        ...   ...
# 47625   Harpenden East  E07000240  St Albans  E07000100  St Albans  3901
# 47626   Harpenden East  E07000240  St Albans  E07000100  St Albans  3901
# 47627   Harpenden East  E07000240  St Albans  E07000100  St Albans  3901
# 47628   Harpenden East  E07000240  St Albans  E07000100  St Albans  3901
# 47629  Harpenden North  E07000240  St Albans  E07000100  St Albans  3901
# 47630  Harpenden North  E07000240  St Albans  E07000100  St Albans  3901
# 47631   Harpenden East  E07000240  St Albans  E07000100  St Albans  3901
# 47632   Wheathampstead  E07000240  St Albans  E07000100  St Albans  3901
# 47633   Wheathampstead  E07000240  St Albans  E07000100  St Albans  3901
# 47634   Harpenden East  E07000240  St Albans  E07000100  St Albans  3901
# 47635   Harpenden East  E07000240  St Albans  E07000100  St Albans  3901
# 47636   Harpenden East  E07000240  St Albans  E07000100  St Albans  3901
# 47637   Harpenden East  E07000240  St Albans  E07000100  St Albans  3901
# 47638   Harpenden West  E07000240  St Albans  E07000100  St Albans  3901
# 47639   Harpenden West  E07000240  St Albans  E07000100  St Albans  3901
# 47640   Harpenden West  E07000240  St Albans  E07000100  St Albans  3901
# 47641   Harpenden West  E07000240  St Albans  E07000100  St Albans  3901
# 47642   Harpenden East  E07000240  St Albans  E07000100  St Albans  3901
# 47643   Harpenden East  E07000240  St Albans  E07000100  St Albans  3901
# 47644   Harpenden East  E07000240  St Albans  E07000100  St Albans  3901
# 47645   Harpenden East  E07000240  St Albans  E07000100  St Albans  3901
# 47646   Harpenden East  E07000240  St Albans  E07000100  St Albans  3901
# 47647   Harpenden East  E07000240  St Albans  E07000100  St Albans  3901
# 47648   Harpenden East  E07000240  St Albans  E07000100  St Albans  3901
# 47649   Harpenden East  E07000240  St Albans  E07000100  St Albans  3901
# 47650   Harpenden East  E07000240  St Albans  E07000100  St Albans  3901
# 47651   Harpenden East  E07000240  St Albans  E07000100  St Albans  3901
# 47652   Harpenden West  E07000240  St Albans  E07000100  St Albans  3901
# 47653           Ashley  E07000240  St Albans  E07000100  St Albans  3901
# 47654      Park Street  E07000240  St Albans  E07000100  St Albans  3901
#
#          LAD17CD    LAD17NM  0_y
# 47104  E07000240  St Albans  429
# 47105  E07000240  St Albans  429
# 47106  E07000240  St Albans  429
# 47107  E07000240  St Albans  429
# 47108  E07000240  St Albans  429
# 47109  E07000240  St Albans  429
# 47110  E07000240  St Albans  429
# 47111  E07000240  St Albans  429
# 47112  E07000240  St Albans  429
# 47113  E07000240  St Albans  429
# 47114  E07000240  St Albans  429
# 47115  E07000240  St Albans  429
# 47116  E07000240  St Albans  429
# 47117  E07000240  St Albans  429
# 47118  E07000240  St Albans  429
# 47119  E07000240  St Albans  429
# 47120  E07000240  St Albans  429
# 47121  E07000240  St Albans  429
# 47122  E07000240  St Albans  429
# 47123  E07000240  St Albans  429
# 47124  E07000240  St Albans  429
# 47125  E07000240  St Albans  429
# 47126  E07000240  St Albans  429
# 47127  E07000240  St Albans  429
# 47128  E07000240  St Albans  429
# 47129  E07000240  St Albans  429
# 47130  E07000240  St Albans  429
# 47131  E07000240  St Albans  429
# 47132  E07000240  St Albans  429
# 47133  E07000240  St Albans  429
# ...          ...        ...  ...
# 47625  E07000240  St Albans  429
# 47626  E07000240  St Albans  429
# 47627  E07000240  St Albans  429
# 47628  E07000240  St Albans  429
# 47629  E07000240  St Albans  429
# 47630  E07000240  St Albans  429
# 47631  E07000240  St Albans  429
# 47632  E07000240  St Albans  429
# 47633  E07000240  St Albans  429
# 47634  E07000240  St Albans  429
# 47635  E07000240  St Albans  429
# 47636  E07000240  St Albans  429
# 47637  E07000240  St Albans  429
# 47638  E07000240  St Albans  429
# 47639  E07000240  St Albans  429
# 47640  E07000240  St Albans  429
# 47641  E07000240  St Albans  429
# 47642  E07000240  St Albans  429
# 47643  E07000240  St Albans  429
# 47644  E07000240  St Albans  429
# 47645  E07000240  St Albans  429
# 47646  E07000240  St Albans  429
# 47647  E07000240  St Albans  429
# 47648  E07000240  St Albans  429
# 47649  E07000240  St Albans  429
# 47650  E07000240  St Albans  429
# 47651  E07000240  St Albans  429
# 47652  E07000240  St Albans  429
# 47653  E07000240  St Albans  429
# 47654  E07000240  St Albans  429
#
# [551 rows x 21 columns]

# %%
cb_df_merged.to_csv('../data/comparison/cb_df_merged.csv')

# %%
aggregagations = {'ids.GB-CHC': 'count'}

cb_lad_pivot_df = pd.pivot_table(cb_df_merged, index=['lad11cd'], aggfunc = aggregagations)
cb_lad_pivot_df.reset_index(inplace=True)

cb_lad_pivot_df = cb_lad_pivot_df[cb_lad_pivot_df['lad11cd'].astype(str).str[0] == 'E']

cb_lad_pivot_df.rename(index=str, columns={'ids.GB-CHC' : 'comparison_Number_of_charities'}, inplace=True)

# %%
cb_lad_pivot_df.head()
# Out:
#      lad11cd  comparison_Number_of_charities
# 0  E06000001                               3
# 1  E06000002                             187
# 2  E06000003                              46
# 3  E06000004                               6
# 4  E06000005                             165

# %%
cb_lad_pivot_df.describe()
# Out:
#        comparison_Number_of_charities
# count                      325.000000
# mean                       243.027692
# std                        246.383526
# min                          2.000000
# 25%                         46.000000
# 50%                        173.000000
# 75%                        360.000000
# max                       1732.000000

# %%
aggregagations = {'ids.GB-CHC': 'count'}

cb_ward_pivot_df = pd.pivot_table(cb_df_merged, index=['WD17CD'], aggfunc = aggregagations)
cb_ward_pivot_df.reset_index(inplace=True)

cb_ward_pivot_df = cb_ward_pivot_df[cb_ward_pivot_df.WD17CD.astype(str).str[0] == 'E']

cb_ward_pivot_df.rename(index=str, columns={'ids.GB-CHC' : 'comparison_Number_of_charities'}, inplace=True)

# %%
cb_ward_pivot_df.head()
# Out:
#       WD17CD  comparison_Number_of_charities
# 0  E05000026                               1
# 1  E05000027                               9
# 2  E05000028                              23
# 3  E05000029                              12
# 4  E05000030                              12

# %%
cb_ward_pivot_df.describe()
# Out:
#        comparison_Number_of_charities
# count                     5296.000000
# mean                        14.913897
# std                         19.973130
# min                          1.000000
# 25%                          2.000000
# 50%                         10.000000
# 75%                         20.000000
# max                        514.000000

# %% [markdown]
# ---
#
# ## Import Population Data
#
# Source - [ONS Open Geography Portal](https://www.ons.gov.uk/peoplepopulationandcommunity/populationandmigration/populationestimates/datasets/wardlevelmidyearpopulationestimatesexperimental)

# %%
pop_ward_df = pd.read_excel('../data/comparison/SAPE20DT8-mid-2017-ward-2017-syoa-estimates-unformatted.xls', sheet_name='Mid-2017 Persons', index_col=[0],skiprows=4)

# %%
pop_ward_df.reset_index(inplace=True)
pop_ward_df = pop_ward_df[['Ward Code 1','Ward Name 1','All Ages']]
pop_ward_df.rename(index=str, columns={'All Ages' : 'comparison_Population_Estimate'}, inplace=True)

# %%
pop_ward_df.head()
# Out:
#   Ward Code 1     Ward Name 1  comparison_Population_Estimate
# 0   E05000026           Abbey                         15460.0
# 1   E05000027          Alibon                         10995.0
# 2   E05000028       Becontree                         14862.0
# 3   E05000029  Chadwell Heath                         11265.0
# 4   E05000030       Eastbrook                         11473.0

# %%
aggregagations = {'pcd8': 'count'}

postcode_df_ward_lad = pd.pivot_table(postcode_df, index=['wd11cd','lad11cd'], aggfunc = aggregagations)
postcode_df_ward_lad.reset_index(inplace=True)

# %%
pop_ward_lad_df = pd.merge(pop_ward_df, ward17_to_lad11_lookup, left_on='Ward Code 1', \
                           right_on='WD17CD',sort=True, how='left')
pop_ward_lad_df = pop_ward_lad_df[pop_ward_lad_df['Ward Code 1'].astype(str).str[0] == 'E']
pop_ward_lad_df = pop_ward_lad_df[pop_ward_lad_df['comparison_Population_Estimate'].notnull()]

# %%
aggregagations = {'comparison_Population_Estimate': 'sum'}

pop_lad_df = pd.pivot_table(pop_ward_lad_df, index=['lad11cd'], aggfunc = aggregagations)
pop_lad_df.reset_index(inplace=True)

# %%
pop_lad_df.head()
# Out:
#      lad11cd  comparison_Population_Estimate
# 0  E06000001                         93019.0
# 1  E06000002                        140639.0
# 2  E06000003                        136005.0
# 3  E06000004                        196487.0
# 4  E06000005                        106347.0

# %% [markdown]
# ---
#
# ## Import Geo-Data: LSOA Level
#
# Source - [ONS Open Geography Portal](http://geoportal.statistics.gov.uk/datasets/lower-layer-super-output-areas-december-2011-super-generalised-clipped-boundaries-in-england-and-wales/data)

# %%
gdf = gpd.read_file('../data/geo/Lower_Layer_Super_Output_Areas_December_2011_Generalised_Clipped__Boundaries_in_England_and_Wales/Lower_Layer_Super_Output_Areas_December_2011_Generalised_Clipped__Boundaries_in_England_and_Wales.shp')
gdf.set_index('lsoa11cd',inplace=True)
gdf.index.names = ['LSOA2011_CD']
gdf = gdf[gdf.index.astype(str).str[0] == 'E']
gdf.reset_index(inplace=True)
gdf['geometry'] = gdf['geometry'].to_crs(epsg=4326)

# %%
gdf.head()
# Out:
#   LSOA2011_CD  objectid                   lsoa11nm                  lsoa11nmw  \
# 0   E01000001         1        City of London 001A        City of London 001A
# 1   E01000002         2        City of London 001B        City of London 001B
# 2   E01000003         3        City of London 001C        City of London 001C
# 3   E01000005         4        City of London 001E        City of London 001E
# 4   E01000006         5  Barking and Dagenham 016A  Barking and Dagenham 016A
#
#       st_areasha   st_lengths  \
# 0  133320.768872  2291.846072
# 1  226191.272990  2433.960112
# 2   57302.966538  1142.359799
# 3  190738.760504  2167.868343
# 4  144195.846857  1935.510354
#
#                                             geometry
# 0  POLYGON ((-0.09728867323202922 51.521577042020...
# 1  POLYGON ((-0.08812915078150368 51.519410719510...
# 2  POLYGON ((-0.0967857370545377 51.5232494901361...
# 3  POLYGON ((-0.07323093900475477 51.510002398683...
# 4  POLYGON ((0.09115207554164177 51.5390853019798...

# %%
display(gdf.loc[0,'geometry'])

# %%
gdf_lsoa = gdf

# %% [markdown]
# ---
#
# ## Import Geo-Data: LAD Level
#
# Source - [ONS Open Geography Portal](http://geoportal.statistics.gov.uk/datasets/local-authority-districts-december-2011-gb-bgc)

# %%
gdf = gpd.read_file('../data/geo/Local_Authority_Districts_December_2011_GB_BGC/Local_Authority_Districts_December_2011_GB_BGC.shp')

gdf.set_index('lad11cd',inplace=True)
gdf.index.names = ['LAD2011_CD']
gdf = gdf[gdf.index.astype(str).str[0] == 'E']
gdf.reset_index(inplace=True)
gdf['geometry'] = gdf['geometry'].to_crs(epsg=4326)

gdf.head()
# Out:
#   LAD2011_CD  objectid lad11cdo               lad11nm lad11nmw    st_areasha  \
# 0  E06000001         1     00EB            Hartlepool     None  9.389290e+07
# 1  E06000002         2     00EC         Middlesbrough     None  5.386184e+07
# 2  E06000003         3     00EE  Redcar and Cleveland     None  2.449159e+08
# 3  E06000004         4     00EF      Stockton-on-Tees     None  2.039201e+08
# 4  E06000039        39     00MD                Slough     None  3.253413e+07
#
#       st_lengths                                           geometry
# 0   68996.677754  (POLYGON ((-1.270237406245723 54.7271584031430...
# 1   44917.925537  (POLYGON ((-1.230015802826847 54.5840956722952...
# 2   93270.866874  (POLYGON ((-1.137165952757933 54.6469344081215...
# 3  155579.742599  (POLYGON ((-1.317985542636292 54.6452624807959...
# 4   43424.361153  POLYGON ((-0.6247880291356083 51.5380032936336...

# %%
display(gdf.loc[0,'geometry'])

# %%
gdf_lad = gdf

# %% [markdown]
# ---
#
# ## Import Geo-Data: Ward Level
#
# Source - [LSOAs 2011 to Wards 2017 lookup table](http://geoportal.statistics.gov.uk/datasets/lower-layer-super-output-area-2011-to-ward-2017-lookup-in-england-and-wales)

# %%
gdf = gpd.read_file('../data/geo/Wards_December_2017_Generalised_Clipped_Boundaries_in_Great_Britain/Wards_December_2017_Generalised_Clipped_Boundaries_in_Great_Britain.shp')

gdf.set_index('wd17cd',inplace=True)
#gdf.index.names = ['LAD2011_CD']
gdf = gdf[gdf.index.astype(str).str[0] == 'E']
gdf.reset_index(inplace=True)
gdf['geometry'] = gdf['geometry'].to_crs(epsg=4326)

gdf.head()
# Out:
#       wd17cd  objectid          wd17nm wd17nmw   bng_e   bng_n      long  \
# 0  E05000026         1           Abbey    None  544434  184378  0.081291
# 1  E05000027         2          Alibon    None  549247  185196  0.150987
# 2  E05000028         3       Becontree    None  546863  185869  0.116912
# 3  E05000029         4  Chadwell Heath    None  548266  189340  0.138596
# 4  E05000030         5       Eastbrook    None  550774  186272  0.173453
#
#          lat    st_areasha   st_lengths  \
# 0  51.539799  1.247620e+06  7858.341538
# 1  51.545898  1.355411e+06  6246.797017
# 2  51.552601  1.289741e+06  6280.315821
# 3  51.583401  3.382318e+06  9496.494913
# 4  51.555199  3.449511e+06  8857.773001
#
#                                             geometry
# 0  (POLYGON ((0.07134621115186986 51.537247597410...
# 1  POLYGON ((0.1563507181798993 51.55101883054941...
# 2  POLYGON ((0.1249895183523908 51.56434101285452...
# 3  POLYGON ((0.1300262084289008 51.5707532745533,...
# 4  POLYGON ((0.1563507181798993 51.55101883054941...

# %%
display(gdf.loc[0,'geometry'])

# %%
gdf_ward = gdf

# %% [markdown]
# ---
#
# ## Map LSOA Deprivation data to Ward Level
#
# Sources:
# * [LSOAs 2011 to Wards 2017 lookup table](http://geoportal.statistics.gov.uk/datasets/lower-layer-super-output-area-2011-to-ward-2017-lookup-in-england-and-wales)
# * [Indices of Deprivation Homepage](https://www.gov.uk/government/statistics/english-indices-of-deprivation-2015) - [File 7: all ranks, deciles and scores for the indices of deprivation, and population denominators](https://www.gov.uk/government/uploads/system/uploads/attachment_data/file/467774/File_7_ID_2015_All_ranks__deciles_and_scores_for_the_Indices_of_Deprivation__and_population_denominators.csv/preview)

# %%
lookup_df = pd.read_csv('../data/geo/Lower_Layer_Super_Output_Area_2011_to_Ward_2017_Lookup_in_England_and_Wales.csv')

#lookup_df.head()

# %%
deprivation_all_df =  pd.read_csv('../data/deprivation/File_7_ID_2015_All_ranks__deciles_and_scores_for_the_Indices_of_Deprivation__and_population_denominators.csv')

#deprivation_all_df.head()

# %%
ward_lsoa_merged = pd.merge(lookup_df, deprivation_all_df, left_on='LSOA11CD', right_on='LSOA code (2011)',sort=True)

deprivation_colums = [{'oldvar': 'Index of Multiple Deprivation (IMD) Score', 'newvar':'comparison_IMD_avg_score'}, \
                        {'oldvar': 'Income Score (rate)', 'newvar':'comparison_Income_avg_score'}, \
                        {'oldvar': 'Employment Score (rate)', 'newvar':'comparison_Employment_avg_score'}, \
                        {'oldvar': 'Education, Skills and Training Score', 'newvar':'comparison_Education_avg_score'}, \
                        {'oldvar': 'Health Deprivation and Disability Score', 'newvar':'comparison_Health_avg_score'}, \
                        {'oldvar': 'Crime Score', 'newvar':'comparison_Crime_avg_score'}, \
                        {'oldvar': 'Barriers to Housing and Services Score', 'newvar':'comparison_Barriers_avg_score'}, \
                        {'oldvar': 'Living Environment Score', 'newvar':'comparison_Living_avg_score'}]


ward_lsoa_merged = ward_lsoa_merged[['LSOA11CD','LSOA11NM','WD17CD','WD17NM','WD17NMW','LAD17CD','LAD17NM']
                                    + [c['oldvar'] for c in deprivation_colums]
                                    + ['Total population: mid 2012 (excluding prisoners)']]
ward_lsoa_merged.head()
# Out:
#     LSOA11CD                   LSOA11NM     WD17CD       WD17NM WD17NMW  \
# 0  E01000001        City of London 001A  E05009288   Aldersgate     NaN
# 1  E01000002        City of London 001B  E05009302  Cripplegate     NaN
# 2  E01000003        City of London 001C  E05009302  Cripplegate     NaN
# 3  E01000005        City of London 001E  E05009308    Portsoken     NaN
# 4  E01000006  Barking and Dagenham 016A  E05000026        Abbey     NaN
#
#      LAD17CD               LAD17NM  Index of Multiple Deprivation (IMD) Score  \
# 0  E09000001        City of London                                      6.063
# 1  E09000001        City of London                                      6.255
# 2  E09000001        City of London                                     19.548
# 3  E09000001        City of London                                     26.005
# 4  E09000002  Barking and Dagenham                                     22.568
#
#    Income Score (rate)  Employment Score (rate)  \
# 0                0.011                    0.015
# 1                0.012                    0.017
# 2                0.105                    0.088
# 3                0.217                    0.144
# 4                0.133                    0.094
#
#    Education, Skills and Training Score  \
# 0                                 0.021
# 1                                 0.040
# 2                                 9.612
# 3                                15.045
# 4                                14.525
#
#    Health Deprivation and Disability Score  Crime Score  \
# 0                                   -1.918       -1.649
# 1                                   -1.931       -1.692
# 2                                    0.321       -0.987
# 3                                    0.050       -0.831
# 4                                   -0.390        0.746
#
#    Barriers to Housing and Services Score  Living Environment Score  \
# 0                                  27.134                    34.502
# 1                                  26.358                    37.106
# 2                                  31.861                    48.337
# 3                                  35.104                    34.811
# 4                                  39.737                    30.477
#
#    Total population: mid 2012 (excluding prisoners)
# 0                                              1469
# 1                                              1469
# 2                                              1421
# 3                                              1014
# 4                                              1794

# %% [markdown]
# #### Calculate population weighted averages of LSOA deprivations for each ward

# %%
wtavg = lambda x, c: np.average(x[c], weights = x['Total population: mid 2012 (excluding prisoners)'], axis = 0)

ward_deprivation = ward_lsoa_merged.groupby(['WD17CD','WD17NM']).size().reset_index(name='LSOA_counts').set_index('WD17CD')

for c in deprivation_colums:
    dfwavg = ward_lsoa_merged.groupby('WD17CD').apply(wtavg, c['oldvar'])
    ward_deprivation = pd.merge(ward_deprivation,pd.DataFrame(dfwavg,columns=[c['newvar']]), on='WD17CD',sort=True)

ward_deprivation = ward_deprivation.reset_index()
ward_deprivation.head()
# Out:
#       WD17CD          WD17NM  LSOA_counts  comparison_IMD_avg_score  \
# 0  E05000026           Abbey            7                 33.084734
# 1  E05000027          Alibon            6                 38.235551
# 2  E05000028       Becontree            8                 35.369455
# 3  E05000029  Chadwell Heath            6                 35.026214
# 4  E05000030       Eastbrook            7                 26.797683
#
#    comparison_Income_avg_score  comparison_Employment_avg_score  \
# 0                     0.224387                         0.122055
# 1                     0.270853                         0.180044
# 2                     0.260072                         0.168042
# 3                     0.234857                         0.157682
# 4                     0.191430                         0.141619
#
#    comparison_Education_avg_score  comparison_Health_avg_score  \
# 0                       16.604366                     0.091863
# 1                       31.023750                     0.588629
# 2                       28.687858                     0.489389
# 3                       28.728325                     0.497478
# 4                       24.290097                     0.178134
#
#    comparison_Crime_avg_score  comparison_Barriers_avg_score  \
# 0                    0.938570                      48.529075
# 1                    1.011638                      36.485621
# 2                    0.871280                      33.679650
# 3                    1.040609                      36.237735
# 4                    0.341267                      32.634020
#
#    comparison_Living_avg_score
# 0                    35.081641
# 1                    25.308429
# 2                    27.403831
# 3                    21.941597
# 4                    20.188132

# %%
ward_deprivation[['comparison_IMD_avg_score']].describe()
# Out:
#        comparison_IMD_avg_score
# count               7427.000000
# mean                  18.912465
# std                   11.613879
# min                    1.269000
# 25%                   10.394736
# 50%                   15.743408
# 75%                   24.834664
# max                   83.416700

# %% [markdown]
# ---
# ## Merge Geo-data and Deprivation data at LAD level

# %%
lad_df = pd.merge(lad_df, lad17_to_lad11_lookup, left_on='LAD2013_CD', right_on='LAD17CD',sort=True)
lad_df.head()
# Out:
#   LAD2013_CD            LAD2013_NM  comparison_IMD_avg_score  \
# 0  E06000001            Hartlepool                    33.178
# 1  E06000002         Middlesbrough                    40.216
# 2  E06000003  Redcar and Cleveland                    28.567
# 3  E06000004      Stockton-on-Tees                    24.625
# 4  E06000005            Darlington                    23.639
#
#    comparison_Income_avg_score  comparison_Employment_avg_score  \
# 0                        0.239                            0.211
# 1                        0.268                            0.216
# 2                        0.204                            0.186
# 3                        0.177                            0.156
# 4                        0.168                            0.150
#
#    comparison_Education_avg_score  comparison_Health_avg_score  \
# 0                          30.510                        0.929
# 1                          40.640                        1.195
# 2                          27.875                        0.752
# 3                          24.637                        0.548
# 4                          22.569                        0.502
#
#    comparison_Crime_avg_score  comparison_Barriers_avg_score  \
# 0                       0.078                         13.128
# 1                       0.633                         18.316
# 2                      -0.013                         12.863
# 3                      -0.263                         17.844
# 4                       0.224                         12.346
#
#    comparison_Living_avg_score    lad11cd               lad11nm   0_x  \
# 0                        8.260  E06000001            Hartlepool  2277
# 1                       12.907  E06000002         Middlesbrough  3193
# 2                        7.923  E06000003  Redcar and Cleveland  3574
# 3                        7.068  E06000004      Stockton-on-Tees  4548
# 4                       10.710  E06000005            Darlington  2472
#
#      LAD17CD               LAD17NM  0_y
# 0  E06000001            Hartlepool  313
# 1  E06000002         Middlesbrough  442
# 2  E06000003  Redcar and Cleveland  464
# 3  E06000004      Stockton-on-Tees  618
# 4  E06000005            Darlington  360

# %%
#combined_gpd = gdf[['st_areasha','st_lengths','geometry']].join(lad_df)
combined_gpd = pd.DataFrame()
combined_gpd = pd.merge(gdf_lad[['LAD2011_CD','st_areasha','st_lengths','geometry']], lad_df, \
                  left_on='LAD2011_CD', right_on='lad11cd',sort=True)

# %%
combined_gpd.head()
# Out:
#   LAD2011_CD    st_areasha     st_lengths  \
# 0  E06000001  9.389290e+07   68996.677754
# 1  E06000002  5.386184e+07   44917.925537
# 2  E06000003  2.449159e+08   93270.866874
# 3  E06000004  2.039201e+08  155579.742599
# 4  E06000005  1.974733e+08  105743.464662
#
#                                             geometry LAD2013_CD  \
# 0  (POLYGON ((-1.270237406245723 54.7271584031430...  E06000001
# 1  (POLYGON ((-1.230015802826847 54.5840956722952...  E06000002
# 2  (POLYGON ((-1.137165952757933 54.6469344081215...  E06000003
# 3  (POLYGON ((-1.317985542636292 54.6452624807959...  E06000004
# 4  POLYGON ((-1.637667569473506 54.61712823531258...  E06000005
#
#              LAD2013_NM  comparison_IMD_avg_score  \
# 0            Hartlepool                    33.178
# 1         Middlesbrough                    40.216
# 2  Redcar and Cleveland                    28.567
# 3      Stockton-on-Tees                    24.625
# 4            Darlington                    23.639
#
#    comparison_Income_avg_score  comparison_Employment_avg_score  \
# 0                        0.239                            0.211
# 1                        0.268                            0.216
# 2                        0.204                            0.186
# 3                        0.177                            0.156
# 4                        0.168                            0.150
#
#    comparison_Education_avg_score  comparison_Health_avg_score  \
# 0                          30.510                        0.929
# 1                          40.640                        1.195
# 2                          27.875                        0.752
# 3                          24.637                        0.548
# 4                          22.569                        0.502
#
#    comparison_Crime_avg_score  comparison_Barriers_avg_score  \
# 0                       0.078                         13.128
# 1                       0.633                         18.316
# 2                      -0.013                         12.863
# 3                      -0.263                         17.844
# 4                       0.224                         12.346
#
#    comparison_Living_avg_score    lad11cd               lad11nm   0_x  \
# 0                        8.260  E06000001            Hartlepool  2277
# 1                       12.907  E06000002         Middlesbrough  3193
# 2                        7.923  E06000003  Redcar and Cleveland  3574
# 3                        7.068  E06000004      Stockton-on-Tees  4548
# 4                       10.710  E06000005            Darlington  2472
#
#      LAD17CD               LAD17NM  0_y
# 0  E06000001            Hartlepool  313
# 1  E06000002         Middlesbrough  442
# 2  E06000003  Redcar and Cleveland  464
# 3  E06000004      Stockton-on-Tees  618
# 4  E06000005            Darlington  360

# %%
filename = '../data/geo/combined_deprivation_lad.json'

try: 
    os.remove(filename)
except OSError:
    pass
combined_gpd.to_file(filename, driver="GeoJSON")

# %%
combined_gpd[['comparison_IMD_avg_score']].describe()
# Out:
#        comparison_IMD_avg_score
# count                326.000000
# mean                  19.463620
# std                    8.004457
# min                    5.009000
# 25%                   12.863750
# 50%                   18.057500
# 75%                   25.210000
# max                   41.997000

# %%
combined_gpd[['comparison_Health_avg_score']].describe()
# Out:
#        comparison_Health_avg_score
# count                   326.000000
# mean                     -0.154037
# std                       0.655901
# min                      -2.191000
# 25%                      -0.638750
# 50%                      -0.201500
# 75%                       0.349250
# max                       1.489000

# %%
combined_gpd_LAD = combined_gpd

# %% [markdown]
# ---
# ## Merge Geo-data and Deprivation data at Ward level

# %%
combined_gpd = pd.DataFrame()
combined_gpd = pd.merge(gdf_ward[['wd17cd','geometry']], ward_deprivation, \
                  left_on='wd17cd', right_on='WD17CD',sort=True)
combined_gpd.drop(columns=['WD17CD'],inplace=True)

# %%
combined_gpd.head()
# Out:
#       wd17cd                                           geometry  \
# 0  E05000026  (POLYGON ((0.07134621115186986 51.537247597410...
# 1  E05000027  POLYGON ((0.1563507181798993 51.55101883054941...
# 2  E05000028  POLYGON ((0.1249895183523908 51.56434101285452...
# 3  E05000029  POLYGON ((0.1300262084289008 51.5707532745533,...
# 4  E05000030  POLYGON ((0.1563507181798993 51.55101883054941...
#
#            WD17NM  LSOA_counts  comparison_IMD_avg_score  \
# 0           Abbey            7                 33.084734
# 1          Alibon            6                 38.235551
# 2       Becontree            8                 35.369455
# 3  Chadwell Heath            6                 35.026214
# 4       Eastbrook            7                 26.797683
#
#    comparison_Income_avg_score  comparison_Employment_avg_score  \
# 0                     0.224387                         0.122055
# 1                     0.270853                         0.180044
# 2                     0.260072                         0.168042
# 3                     0.234857                         0.157682
# 4                     0.191430                         0.141619
#
#    comparison_Education_avg_score  comparison_Health_avg_score  \
# 0                       16.604366                     0.091863
# 1                       31.023750                     0.588629
# 2                       28.687858                     0.489389
# 3                       28.728325                     0.497478
# 4                       24.290097                     0.178134
#
#    comparison_Crime_avg_score  comparison_Barriers_avg_score  \
# 0                    0.938570                      48.529075
# 1                    1.011638                      36.485621
# 2                    0.871280                      33.679650
# 3                    1.040609                      36.237735
# 4                    0.341267                      32.634020
#
#    comparison_Living_avg_score
# 0                    35.081641
# 1                    25.308429
# 2                    27.403831
# 3                    21.941597
# 4                    20.188132

# %%
filename = '../data/geo/combined_deprivation_ward.json'

try: 
    os.remove(filename)
except OSError:
    pass
combined_gpd.to_file(filename, driver="GeoJSON")

# %%
combined_gpd_ward = combined_gpd

# %% [markdown]
# ## Export just the Geo-data and Geo-code to place names lookup

# %% [markdown]
# ### Ward level

# %%
gdf = gpd.read_file('../data/geo/Wards_December_2017_Generalised_Clipped_Boundaries_in_Great_Britain/Wards_December_2017_Generalised_Clipped_Boundaries_in_Great_Britain.shp')

gdf.set_index('wd17cd',inplace=True)
#gdf.index.names = ['LAD2011_CD']
gdf = gdf[gdf.index.astype(str).str[0] == 'E']
gdf.reset_index(inplace=True)
gdf['geometry'] = gdf['geometry'].to_crs(epsg=4326)

filename = '../data/geo/geo_eng_ward.json'

try: 
    os.remove(filename)
except OSError:
    pass
gdf.to_file(filename, driver="GeoJSON")

# %% [markdown]
# ### Ward level Lookup

# %%
filename_for_lookup = '../data/geo/geo_eng_ward_lookup.json'

df_for_lookup = pd.DataFrame(gdf)
df_for_lookup = df_for_lookup[['wd17cd','wd17nm']]
df_for_lookup.rename(columns={'wd17cd':'index','wd17nm':'value'},inplace=True)
df_for_lookup['key']=df_for_lookup['index']
df_for_lookup.set_index('index',inplace=True)

try: 
    os.remove(filename_for_lookup)
except OSError:
    pass
df_for_lookup.to_json(filename_for_lookup,orient='index')

# %% [markdown]
# ### LAD level

# %%
gdf = gpd.read_file('../data/geo/Local_Authority_Districts_December_2011_GB_BGC/Local_Authority_Districts_December_2011_GB_BGC.shp')
gdf.set_index('lad11cd',inplace=True)
gdf.index.names = ['LAD2011_CD']
gdf = gdf[gdf.index.astype(str).str[0] == 'E']
gdf.reset_index(inplace=True)
gdf['geometry'] = gdf['geometry'].to_crs(epsg=4326)

filename = '../data/geo/geo_eng_LAD.json'

try: 
    os.remove(filename)
except OSError:
    pass
gdf.to_file(filename, driver="GeoJSON")

# %% [markdown]
# ### LAD level lookup

# %%
filename_for_lookup = '../data/geo/geo_eng_LAD_lookup.json'

df_for_lookup = pd.DataFrame(gdf)
df_for_lookup = df_for_lookup[['LAD2011_CD','lad11nm']]
df_for_lookup.rename(columns={'LAD2011_CD':'index','lad11nm':'value'},inplace=True)
df_for_lookup['key']=df_for_lookup['index']
df_for_lookup.set_index('index',inplace=True)

try: 
    os.remove(filename_for_lookup)
except OSError:
    pass
df_for_lookup.to_json(filename_for_lookup,orient='index')

# %% [markdown]
# ## Export just the Deprivation data

# %% [markdown]
# ### Ward level

# %%
ward_deprivation.head()
# Out:
#       WD17CD          WD17NM  LSOA_counts  comparison_IMD_avg_score  \
# 0  E05000026           Abbey            7                 33.084734
# 1  E05000027          Alibon            6                 38.235551
# 2  E05000028       Becontree            8                 35.369455
# 3  E05000029  Chadwell Heath            6                 35.026214
# 4  E05000030       Eastbrook            7                 26.797683
#
#    comparison_Income_avg_score  comparison_Employment_avg_score  \
# 0                     0.224387                         0.122055
# 1                     0.270853                         0.180044
# 2                     0.260072                         0.168042
# 3                     0.234857                         0.157682
# 4                     0.191430                         0.141619
#
#    comparison_Education_avg_score  comparison_Health_avg_score  \
# 0                       16.604366                     0.091863
# 1                       31.023750                     0.588629
# 2                       28.687858                     0.489389
# 3                       28.728325                     0.497478
# 4                       24.290097                     0.178134
#
#    comparison_Crime_avg_score  comparison_Barriers_avg_score  \
# 0                    0.938570                      48.529075
# 1                    1.011638                      36.485621
# 2                    0.871280                      33.679650
# 3                    1.040609                      36.237735
# 4                    0.341267                      32.634020
#
#    comparison_Living_avg_score
# 0                    35.081641
# 1                    25.308429
# 2                    27.403831
# 3                    21.941597
# 4                    20.188132

# %%
out = '[' + ward_deprivation.to_json(orient='records')[1:-1] + ']'
with open('../data/comparison/comparison_eng_ward_deprivation.json', 'w') as f:
    f.write(out)

# %%
ward_deprivation.to_csv('../data/comparison/comparison_eng_ward_deprivation.csv.gz', compression='gzip')
ward_deprivation.to_csv('../data/comparison/comparison_eng_ward_deprivation.csv')

# %% [markdown]
# ### LAD level

# %%
lad_df.head()
# Out:
#   LAD2013_CD            LAD2013_NM  comparison_IMD_avg_score  \
# 0  E06000001            Hartlepool                    33.178
# 1  E06000002         Middlesbrough                    40.216
# 2  E06000003  Redcar and Cleveland                    28.567
# 3  E06000004      Stockton-on-Tees                    24.625
# 4  E06000005            Darlington                    23.639
#
#    comparison_Income_avg_score  comparison_Employment_avg_score  \
# 0                        0.239                            0.211
# 1                        0.268                            0.216
# 2                        0.204                            0.186
# 3                        0.177                            0.156
# 4                        0.168                            0.150
#
#    comparison_Education_avg_score  comparison_Health_avg_score  \
# 0                          30.510                        0.929
# 1                          40.640                        1.195
# 2                          27.875                        0.752
# 3                          24.637                        0.548
# 4                          22.569                        0.502
#
#    comparison_Crime_avg_score  comparison_Barriers_avg_score  \
# 0                       0.078                         13.128
# 1                       0.633                         18.316
# 2                      -0.013                         12.863
# 3                      -0.263                         17.844
# 4                       0.224                         12.346
#
#    comparison_Living_avg_score    lad11cd               lad11nm   0_x  \
# 0                        8.260  E06000001            Hartlepool  2277
# 1                       12.907  E06000002         Middlesbrough  3193
# 2                        7.923  E06000003  Redcar and Cleveland  3574
# 3                        7.068  E06000004      Stockton-on-Tees  4548
# 4                       10.710  E06000005            Darlington  2472
#
#      LAD17CD               LAD17NM  0_y
# 0  E06000001            Hartlepool  313
# 1  E06000002         Middlesbrough  442
# 2  E06000003  Redcar and Cleveland  464
# 3  E06000004      Stockton-on-Tees  618
# 4  E06000005            Darlington  360

# %%
out = '[' + lad_df.to_json(orient='records')[1:-1] + ']'
with open('../data/comparison/comparison_eng_LAD_deprivation.json', 'w') as f:
    f.write(out)

# %%
lad_df.to_csv('../data/comparison/comparison_eng_LAD_deprivation.csv.gz', compression='gzip')
lad_df.to_csv('../data/comparison/comparison_eng_LAD_deprivation.csv')

# %% [markdown]
# ## Export just comparison data

# %% [markdown]
# ### Number of charities - LAD level

# %%
cb_lad_pivot_df.head()
# Out:
#      lad11cd  comparison_Number_of_charities
# 0  E06000001                               3
# 1  E06000002                             187
# 2  E06000003                              46
# 3  E06000004                               6
# 4  E06000005                             165

# %%
out = '[' + cb_lad_pivot_df.to_json(orient='records')[1:-1] + ']'
with open('../data/comparison/comparison_eng_LAD_charities.json', 'w') as f:
    f.write(out)

# %%
cb_lad_pivot_df.to_csv('../data/comparison/comparison_eng_LAD_charities.csv')

# %% [markdown]
# ### Number of charities - Ward level

# %%
cb_ward_pivot_df.head()
# Out:
#       WD17CD  comparison_Number_of_charities
# 0  E05000026                               1
# 1  E05000027                               9
# 2  E05000028                              23
# 3  E05000029                              12
# 4  E05000030                              12

# %%
out = '[' + cb_ward_pivot_df.to_json(orient='records')[1:-1] + ']'
with open('../data/comparison/comparison_eng_ward_charities.json', 'w') as f:
    f.write(out)

# %%
cb_ward_pivot_df.to_csv('../data/comparison/comparison_eng_ward_charities.csv')

# %% [markdown]
# ### Population 2017 - LAD level

# %%
pop_lad_df.head()
# Out:
#      lad11cd  comparison_Population_Estimate
# 0  E06000001                         93019.0
# 1  E06000002                        140639.0
# 2  E06000003                        136005.0
# 3  E06000004                        196487.0
# 4  E06000005                        106347.0

# %%
pop_lad_df.to_csv('../data/comparison/comparison_eng_LAD_population.csv')

# %% [markdown]
# ### Population 2017 - Ward level

# %%
pop_ward_df.head()
# Out:
#   Ward Code 1     Ward Name 1  comparison_Population_Estimate
# 0   E05000026           Abbey                         15460.0
# 1   E05000027          Alibon                         10995.0
# 2   E05000028       Becontree                         14862.0
# 3   E05000029  Chadwell Heath                         11265.0
# 4   E05000030       Eastbrook                         11473.0

# %%
pop_ward_df.to_csv('../data/comparison/comparison_eng_ward_population.csv')

# %% [markdown]
# # Check Data Inconsistencies
