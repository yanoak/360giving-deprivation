# %%
import pandas as pd
import numpy as np
from IPython.display import display, HTML
pd.set_option('display.max_columns', 300)


# %matplotlib inline
import random
import matplotlib.pyplot as plt
import seaborn as sns

import datetime
import dateutil

# %% [markdown]
# ---
#
# ## Export Group by Donor, Year, District

# %%
original_df = pd.read_csv('../data/grantnav-20181123024823.csv', low_memory=False)
df = original_df

# %%
df.head()
# Out:
#                Identifier                                          Title  \
# 0  360G-SE-2010005783LOTT                JUNIOR CLUB DEVELOPMENT PROJECT
# 1  360G-SE-2010007937LOTT                           Urban X BBall League
# 2    360G-SE-20088202LOTT            Suffolk Sport Core Services 2009-12
# 3  360G-SE-2010007591LOTT                                Valley of Dance
# 4    360G-SE-20066240LOTT  South Wilts Sports Club: Hub Club Application
#
#                                          Description Currency  \
# 0  Funding under Sport England's Small Grants fun...      GBP
# 1  Funding under Sport England's Small Grants fun...      GBP
# 2  Funding under Sport England's Community Progra...      GBP
# 3  Funding under Sport England's Small Grants fun...      GBP
# 4  Funding under Sport England's Community Progra...      GBP
#
#    Amount Applied For  Amount Awarded  Amount Disbursed  \
# 0                 NaN          5800.0            5800.0
# 1                 NaN          9550.0            9550.0
# 2                 NaN        600000.0               NaN
# 3                 NaN          7300.0            7300.0
# 4                 NaN        200000.0          200000.0
#
#                   Award Date  URL   Planned Dates:Start Date  \
# 0  2010-09-29T00:00:00+00:00  NaN  2010-09-01T00:00:00+00:00
# 1  2010-09-29T00:00:00+00:00  NaN  2010-09-01T00:00:00+00:00
# 2  2010-09-30T00:00:00+00:00  NaN                        NaN
# 3  2010-10-01T00:00:00+00:00  NaN  2010-09-13T00:00:00+00:00
# 4  2010-10-04T00:00:00+00:00  NaN  2010-10-01T00:00:00+00:00
#
#       Planned Dates:End Date  Planned Dates:Duration (months)  \
# 0  2011-08-31T00:00:00+00:00                             12.0
# 1  2011-04-01T00:00:00+00:00                              7.0
# 2                        NaN                              NaN
# 3  2011-07-31T00:00:00+00:00                             11.0
# 4  2014-04-30T00:00:00+00:00                             43.0
#
#    Actual Dates:Start Date Actual Dates:End Date  \
# 0                      NaN                   NaN
# 1                      NaN                   NaN
# 2                      NaN                   NaN
# 3                      NaN                   NaN
# 4                      NaN                   NaN
#
#    Actual Dates:Duration (months) Recipient Org:Identifier  \
# 0                             NaN       360G-SE-2010005783
# 1                             NaN          GB-COH-06113662
# 2                             NaN         360G-SE-20088202
# 3                             NaN       360G-SE-2010007591
# 4                             NaN         360G-SE-20066240
#
#                     Recipient Org:Name Recipient Org:Charity Number  \
# 0                   BARKERS' BUTTS RFC                          NaN
# 1                      MBA Association                      1119750
# 2     Suffolk Coastal District Council                          NaN
# 3     Wellhouse Junior & Infant School                          NaN
# 4  Salisbury & South Wilts Sports Club                          NaN
#
#   Recipient Org:Company Number Recipient Org:Postal Code  \
# 0                          NaN                   CV5 9AR
# 1                     06113662                   SG1 5RD
# 2                          NaN                  IP12 1AU
# 3                          NaN                   HD7 4ES
# 4                          NaN                   SP2 9NY
#
#   Recipient Org:Location:0:Geographic Code Type  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Recipient Org:Location:0:Geographic Code Recipient Org:Location:0:Name  \
# 0                                      NaN                           NaN
# 1                                      NaN                           NaN
# 2                                      NaN                           NaN
# 3                                      NaN                           NaN
# 4                                      NaN                           NaN
#
#   Recipient Org:Location:1:Geographic Code Type  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Recipient Org:Location:1:Geographic Code Recipient Org:Location:1:Name  \
# 0                                      NaN                           NaN
# 1                                      NaN                           NaN
# 2                                      NaN                           NaN
# 3                                      NaN                           NaN
# 4                                      NaN                           NaN
#
#    Recipient Org:Location:2:Geographic Code Type  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    Recipient Org:Location:2:Geographic Code  Recipient Org:Location:2:Name  \
# 0                                       NaN                            NaN
# 1                                       NaN                            NaN
# 2                                       NaN                            NaN
# 3                                       NaN                            NaN
# 4                                       NaN                            NaN
#
#   Funding Org:Identifier Funding Org:Name Funding Org:Postal Code  \
# 0        GB-COH-RC000766    Sport England                     NaN
# 1        GB-COH-RC000766    Sport England                     NaN
# 2        GB-COH-RC000766    Sport England                     NaN
# 3        GB-COH-RC000766    Sport England                     NaN
# 4        GB-COH-RC000766    Sport England                     NaN
#
#   Grant Programme:Code Grant Programme:Title  \
# 0                   SG          Small Grants
# 1                   SG          Small Grants
# 2                   CP   Community Programme
# 3                   SG          Small Grants
# 4                   CP   Community Programme
#
#                    Grant Programme:URL Beneficiary Location:0:Name  \
# 0  http://www.sportengland.org/funding                     CV5 9AR
# 1  http://www.sportengland.org/funding                     SG5 1JB
# 2  http://www.sportengland.org/funding                    IP12 1AU
# 3  http://www.sportengland.org/funding                     HD7 4BE
# 4  http://www.sportengland.org/funding                     SP2 9NY
#
#   Beneficiary Location:0:Country Code Beneficiary Location:0:Geographic Code  \
# 0                                  GB                                    NaN
# 1                                  GB                                    NaN
# 2                                  GB                                    NaN
# 3                                  GB                                    NaN
# 4                                  GB                                    NaN
#
#   Beneficiary Location:0:Geographic Code Type Beneficiary Location:1:Name  \
# 0                                         NaN         Coventry North West
# 1                                         NaN       Hitchin and Harpenden
# 2                                         NaN             Suffolk Coastal
# 3                                         NaN                Colne Valley
# 4                                         NaN                   Salisbury
#
#   Beneficiary Location:1:Country Code Beneficiary Location:1:Geographic Code  \
# 0                                 NaN                              E14000650
# 1                                 NaN                              E14000749
# 2                                 NaN                              E14000981
# 3                                 NaN                              E14000645
# 4                                 NaN                              E14000912
#
#   Beneficiary Location:1:Geographic Code Type Beneficiary Location:2:Name  \
# 0                                         WPC                    Coventry
# 1                                         WPC         North Hertfordshire
# 2                                         WPC             Suffolk Coastal
# 3                                         WPC                    Kirklees
# 4                                         WPC                   Wiltshire
#
#   Beneficiary Location:2:Country Code Beneficiary Location:2:Geographic Code  \
# 0                                 NaN                              E08000026
# 1                                 NaN                              E07000099
# 2                                 NaN                              E07000205
# 3                                 NaN                              E08000034
# 4                                 NaN                              E06000054
#
#   Beneficiary Location:2:Geographic Code Type Beneficiary Location:3:Name  \
# 0                                         LAD                         NaN
# 1                                         LAD                         NaN
# 2                                         LAD                         NaN
# 3                                         LAD                         NaN
# 4                                         LAD                         NaN
#
#    Beneficiary Location:3:Country Code Beneficiary Location:3:Geographic Code  \
# 0                                  NaN                              E01009523
# 1                                  NaN                              E01023616
# 2                                  NaN                              E01030211
# 3                                  NaN                              E01011148
# 4                                  NaN                              E01032001
#
#   Beneficiary Location:3:Geographic Code Type Beneficiary Location:4:Name  \
# 0                                        LSOA                         NaN
# 1                                        LSOA                         NaN
# 2                                        LSOA                         NaN
# 3                                        LSOA                         NaN
# 4                                        LSOA                         NaN
#
#    Beneficiary Location:4:Country Code Beneficiary Location:4:Geographic Code  \
# 0                                  NaN                                    NaN
# 1                                  NaN                                    NaN
# 2                                  NaN                                    NaN
# 3                                  NaN                                    NaN
# 4                                  NaN                                    NaN
#
#   Beneficiary Location:4:Geographic Code Type Beneficiary Location:5:Name  \
# 0                                         NaN                         NaN
# 1                                         NaN                         NaN
# 2                                         NaN                         NaN
# 3                                         NaN                         NaN
# 4                                         NaN                         NaN
#
#    Beneficiary Location:5:Country Code Beneficiary Location:5:Geographic Code  \
# 0                                  NaN                                    NaN
# 1                                  NaN                                    NaN
# 2                                  NaN                                    NaN
# 3                                  NaN                                    NaN
# 4                                  NaN                                    NaN
#
#   Beneficiary Location:5:Geographic Code Type Beneficiary Location:6:Name  \
# 0                                         NaN                         NaN
# 1                                         NaN                         NaN
# 2                                         NaN                         NaN
# 3                                         NaN                         NaN
# 4                                         NaN                         NaN
#
#    Beneficiary Location:6:Country Code Beneficiary Location:6:Geographic Code  \
# 0                                  NaN                                    NaN
# 1                                  NaN                                    NaN
# 2                                  NaN                                    NaN
# 3                                  NaN                                    NaN
# 4                                  NaN                                    NaN
#
#   Beneficiary Location:6:Geographic Code Type Beneficiary Location:7:Name  \
# 0                                         NaN                         NaN
# 1                                         NaN                         NaN
# 2                                         NaN                         NaN
# 3                                         NaN                         NaN
# 4                                         NaN                         NaN
#
#    Beneficiary Location:7:Country Code Beneficiary Location:7:Geographic Code  \
# 0                                  NaN                                    NaN
# 1                                  NaN                                    NaN
# 2                                  NaN                                    NaN
# 3                                  NaN                                    NaN
# 4                                  NaN                                    NaN
#
#   Beneficiary Location:7:Geographic Code Type From An Open Call?  \
# 0                                         NaN                Yes
# 1                                         NaN                Yes
# 2                                         NaN                Yes
# 3                                         NaN                Yes
# 4                                         NaN                Yes
#
#    The following fields are not in the 360 Giving Standard and are added by GrantNav.  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Data Source Publisher:Name  \
# 0  https://www.sportengland.org/media/12725/360gi...  Sport England
# 1  https://www.sportengland.org/media/12725/360gi...  Sport England
# 2  https://www.sportengland.org/media/12725/360gi...  Sport England
# 3  https://www.sportengland.org/media/12725/360gi...  Sport England
# 4  https://www.sportengland.org/media/12725/360gi...  Sport England
#
#            Recipient Region        Recipient District  \
# 0             West Midlands         Coventry District
# 1           East of England        Stevenage District
# 2           East of England  Suffolk Coastal District
# 3  Yorkshire and the Humber         Kirklees District
# 4                South West                 Wiltshire
#
#   Recipient District Geographic Code  \
# 0                          E08000026
# 1                          E07000243
# 2                          E07000205
# 3                          E08000034
# 4                          E06000054
#
#                                 Recipient Ward Recipient Ward Geographic Code  \
# 0                                 Bablake Ward                      E05001218
# 1                            Martins Wood Ward                      E05004810
# 2                              Woodbridge Ward                      E05010457
# 3                            Colne Valley Ward                      E05008559
# 4  Salisbury Fisherton and Bemerton Village ED                      E05008387
#
#   Retrieved for use in GrantNav  \
# 0     2018-11-06T08:34:42+00:00
# 1     2018-11-06T08:34:42+00:00
# 2     2018-11-06T08:34:42+00:00
# 3     2018-11-06T08:34:42+00:00
# 4     2018-11-06T08:34:42+00:00
#
#                                   License (see note)  \
# 0  http://www.nationalarchives.gov.uk/doc/open-go...
# 1  http://www.nationalarchives.gov.uk/doc/open-go...
# 2  http://www.nationalarchives.gov.uk/doc/open-go...
# 3  http://www.nationalarchives.gov.uk/doc/open-go...
# 4  http://www.nationalarchives.gov.uk/doc/open-go...
#
#    Note, this file also contains OS data © Crown copyright and database right 2016, Royal Mail data © Royal Mail copyright and Database right 2016, National Statistics data © Crown copyright and database right 2015 & 2016, see http://grantnav.threesixtygiving.org/datasets/ for more information.
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df['Award Year'] = pd.to_datetime(df['Award Date']).dt.year
df = df[df['Award Year'] >= 2013]
df.head()
# Out:
#                   Identifier  \
# 629     360G-JRF-YCFEB201804
# 670     360G-JRF-YCMAY201814
# 671     360G-JRF-YCMAY201815
# 672     360G-JRF-YCMAY201817
# 673  360G-CheshireCF-A459157
#
#                                                  Title  \
# 629  Changing the lives of the over 50's with Exper...
# 670             St Barnabas Summer Holiday Club (2018)
# 671                                    Plant Tang Hall
# 672           York LGBT Health and Wellbeing Programme
# 673                                      Fallen Angels
#
#                                            Description Currency  \
# 629  To fund a 5-weekly employment and training pro...      GBP
# 670  To fund subsidised places for families who are...      GBP
# 671  To fund a community-led food growing group, wh...      GBP
# 672  To fund a number of volunteer led health and w...      GBP
# 673  The Comic Relief Core Strengths funding will e...      GBP
#
#      Amount Applied For  Amount Awarded  Amount Disbursed  \
# 629                 NaN          7615.0               NaN
# 670                 NaN           540.0               NaN
# 671                 NaN          9664.0               NaN
# 672                 NaN          3620.0               NaN
# 673              5000.0          4440.0               NaN
#
#                     Award Date                                         URL  \
# 629  2018-02-21T00:00:00+00:00                                         NaN
# 670  2018-05-17T00:00:00+00:00                                         NaN
# 671  2018-05-17T00:00:00+00:00                                         NaN
# 672  2018-05-17T00:00:00+00:00                                         NaN
# 673  2017-11-23T00:00:00+00:00  https://www.fallenangelsdancetheatre.co.uk
#
#       Planned Dates:Start Date     Planned Dates:End Date  \
# 629                        NaN                        NaN
# 670                        NaN                        NaN
# 671                        NaN                        NaN
# 672                        NaN                        NaN
# 673  2017-12-04T00:00:00+00:00  2018-04-30T00:00:00+00:00
#
#      Planned Dates:Duration (months)  Actual Dates:Start Date  \
# 629                              NaN                      NaN
# 670                              NaN                      NaN
# 671                              NaN                      NaN
# 672                              NaN                      NaN
# 673                              NaN                      NaN
#
#     Actual Dates:End Date  Actual Dates:Duration (months)  \
# 629                   NaN                             NaN
# 670                   NaN                             NaN
# 671                   NaN                             NaN
# 672                   NaN                             NaN
# 673                   NaN                             NaN
#
#     Recipient Org:Identifier                      Recipient Org:Name  \
# 629          GB-COH-10421223            Experience Counts (York) CIC
# 670           GB-CHC-1113528          St Barnabas Out of School Club
# 671           GB-CHC-1155478              Tang Hall Community Centre
# 672          GB-CHC-1162234                          York LGBT Forum
# 673           GB-CHC-1158251  Fallen Angels Dance Theatre North West
#
#     Recipient Org:Charity Number Recipient Org:Company Number  \
# 629                          NaN                     10421223
# 670                      1113528                          NaN
# 671                      1155478                          NaN
# 672                      1162234                          NaN
# 673                      1158251                      8909000
#
#     Recipient Org:Postal Code Recipient Org:Location:0:Geographic Code Type  \
# 629                       NaN                                           NaN
# 670                       NaN                                           NaN
# 671                       NaN                                           NaN
# 672                       NaN                                           NaN
# 673                   CH3 5NX                                           NaN
#
#     Recipient Org:Location:0:Geographic Code Recipient Org:Location:0:Name  \
# 629                                      NaN                           NaN
# 670                                      NaN                           NaN
# 671                                      NaN                           NaN
# 672                                      NaN                           NaN
# 673                                      NaN                           NaN
#
#     Recipient Org:Location:1:Geographic Code Type  \
# 629                                           NaN
# 670                                           NaN
# 671                                           NaN
# 672                                           NaN
# 673                                           NaN
#
#     Recipient Org:Location:1:Geographic Code Recipient Org:Location:1:Name  \
# 629                                      NaN                           NaN
# 670                                      NaN                           NaN
# 671                                      NaN                           NaN
# 672                                      NaN                           NaN
# 673                                      NaN                           NaN
#
#      Recipient Org:Location:2:Geographic Code Type  \
# 629                                            NaN
# 670                                            NaN
# 671                                            NaN
# 672                                            NaN
# 673                                            NaN
#
#      Recipient Org:Location:2:Geographic Code  Recipient Org:Location:2:Name  \
# 629                                       NaN                            NaN
# 670                                       NaN                            NaN
# 671                                       NaN                            NaN
# 672                                       NaN                            NaN
# 673                                       NaN                            NaN
#
#     Funding Org:Identifier               Funding Org:Name  \
# 629          GB-CHC-210169     Joseph Rowntree Foundation
# 670          GB-CHC-210169     Joseph Rowntree Foundation
# 671          GB-CHC-210169     Joseph Rowntree Foundation
# 672          GB-CHC-210169     Joseph Rowntree Foundation
# 673         GB-CHC-1143711  Cheshire Community Foundation
#
#     Funding Org:Postal Code Grant Programme:Code  \
# 629                     NaN                  NaN
# 670                     NaN                  NaN
# 671                     NaN                  NaN
# 672                     NaN                  NaN
# 673                     NaN                  NaN
#
#                                 Grant Programme:Title Grant Programme:URL  \
# 629                                               NaN                 NaN
# 670                                               NaN                 NaN
# 671                                               NaN                 NaN
# 672                                               NaN                 NaN
# 673  Comic Relief Core Strength For Local Communities                 NaN
#
#              Beneficiary Location:0:Name Beneficiary Location:0:Country Code  \
# 629  Acomb, Guildhall, and York Citywide                                 NaN
# 670                              Holgate                                 NaN
# 671                Heworth and Hull Road                                 NaN
# 672                        York Citywide                                 NaN
# 673                        Cheshire East                                 NaN
#
#                 Beneficiary Location:0:Geographic Code  \
# 629  E05010311 (Acomb), E05010318 (Guildhall) and E...
# 670                                         E05010322
# 671      E05010320 (Heworth) and E05010323 (Hull Road)
# 672                                         E06000014
# 673                                                NaN
#
#     Beneficiary Location:0:Geographic Code Type Beneficiary Location:1:Name  \
# 629                                          WD                         NaN
# 670                                          WD                         NaN
# 671                                          WD                         NaN
# 672                                          UA                         NaN
# 673                                         NaN                         NaN
#
#     Beneficiary Location:1:Country Code  \
# 629                                 NaN
# 670                                 NaN
# 671                                 NaN
# 672                                 NaN
# 673                                 NaN
#
#     Beneficiary Location:1:Geographic Code  \
# 629                                    NaN
# 670                                    NaN
# 671                                    NaN
# 672                                    NaN
# 673                                    NaN
#
#     Beneficiary Location:1:Geographic Code Type Beneficiary Location:2:Name  \
# 629                                         NaN                         NaN
# 670                                         NaN                         NaN
# 671                                         NaN                         NaN
# 672                                         NaN                         NaN
# 673                                         NaN                         NaN
#
#     Beneficiary Location:2:Country Code  \
# 629                                 NaN
# 670                                 NaN
# 671                                 NaN
# 672                                 NaN
# 673                                 NaN
#
#     Beneficiary Location:2:Geographic Code  \
# 629                                    NaN
# 670                                    NaN
# 671                                    NaN
# 672                                    NaN
# 673                                    NaN
#
#     Beneficiary Location:2:Geographic Code Type Beneficiary Location:3:Name  \
# 629                                         NaN                         NaN
# 670                                         NaN                         NaN
# 671                                         NaN                         NaN
# 672                                         NaN                         NaN
# 673                                         NaN                         NaN
#
#      Beneficiary Location:3:Country Code  \
# 629                                  NaN
# 670                                  NaN
# 671                                  NaN
# 672                                  NaN
# 673                                  NaN
#
#     Beneficiary Location:3:Geographic Code  \
# 629                                    NaN
# 670                                    NaN
# 671                                    NaN
# 672                                    NaN
# 673                                    NaN
#
#     Beneficiary Location:3:Geographic Code Type Beneficiary Location:4:Name  \
# 629                                         NaN                         NaN
# 670                                         NaN                         NaN
# 671                                         NaN                         NaN
# 672                                         NaN                         NaN
# 673                                         NaN                         NaN
#
#      Beneficiary Location:4:Country Code  \
# 629                                  NaN
# 670                                  NaN
# 671                                  NaN
# 672                                  NaN
# 673                                  NaN
#
#     Beneficiary Location:4:Geographic Code  \
# 629                                    NaN
# 670                                    NaN
# 671                                    NaN
# 672                                    NaN
# 673                                    NaN
#
#     Beneficiary Location:4:Geographic Code Type Beneficiary Location:5:Name  \
# 629                                         NaN                         NaN
# 670                                         NaN                         NaN
# 671                                         NaN                         NaN
# 672                                         NaN                         NaN
# 673                                         NaN                         NaN
#
#      Beneficiary Location:5:Country Code  \
# 629                                  NaN
# 670                                  NaN
# 671                                  NaN
# 672                                  NaN
# 673                                  NaN
#
#     Beneficiary Location:5:Geographic Code  \
# 629                                    NaN
# 670                                    NaN
# 671                                    NaN
# 672                                    NaN
# 673                                    NaN
#
#     Beneficiary Location:5:Geographic Code Type Beneficiary Location:6:Name  \
# 629                                         NaN                         NaN
# 670                                         NaN                         NaN
# 671                                         NaN                         NaN
# 672                                         NaN                         NaN
# 673                                         NaN                         NaN
#
#      Beneficiary Location:6:Country Code  \
# 629                                  NaN
# 670                                  NaN
# 671                                  NaN
# 672                                  NaN
# 673                                  NaN
#
#     Beneficiary Location:6:Geographic Code  \
# 629                                    NaN
# 670                                    NaN
# 671                                    NaN
# 672                                    NaN
# 673                                    NaN
#
#     Beneficiary Location:6:Geographic Code Type Beneficiary Location:7:Name  \
# 629                                         NaN                         NaN
# 670                                         NaN                         NaN
# 671                                         NaN                         NaN
# 672                                         NaN                         NaN
# 673                                         NaN                         NaN
#
#      Beneficiary Location:7:Country Code  \
# 629                                  NaN
# 670                                  NaN
# 671                                  NaN
# 672                                  NaN
# 673                                  NaN
#
#     Beneficiary Location:7:Geographic Code  \
# 629                                    NaN
# 670                                    NaN
# 671                                    NaN
# 672                                    NaN
# 673                                    NaN
#
#     Beneficiary Location:7:Geographic Code Type From An Open Call?  \
# 629                                         NaN                Yes
# 670                                         NaN                Yes
# 671                                         NaN                Yes
# 672                                         NaN                Yes
# 673                                         NaN                NaN
#
#      The following fields are not in the 360 Giving Standard and are added by GrantNav.  \
# 629                                                NaN
# 670                                                NaN
# 671                                                NaN
# 672                                                NaN
# 673                                                NaN
#
#                                            Data Source  \
# 629  https://www.jrf.org.uk/sites/default/files/jrf...
# 670  https://www.jrf.org.uk/sites/default/files/jrf...
# 671  https://www.jrf.org.uk/sites/default/files/jrf...
# 672  https://www.jrf.org.uk/sites/default/files/jrf...
# 673  http://cheshirecommunityfoundation.org.uk/wp-c...
#
#                     Publisher:Name Recipient Region  \
# 629     Joseph Rowntree Foundation              NaN
# 670     Joseph Rowntree Foundation              NaN
# 671     Joseph Rowntree Foundation              NaN
# 672     Joseph Rowntree Foundation              NaN
# 673  Cheshire Community Foundation       North West
#
#             Recipient District Recipient District Geographic Code  \
# 629                        NaN                                NaN
# 670                        NaN                                NaN
# 671                        NaN                                NaN
# 672                        NaN                                NaN
# 673  Cheshire West and Chester                          E06000050
#
#           Recipient Ward Recipient Ward Geographic Code  \
# 629                  NaN                            NaN
# 670                  NaN                            NaN
# 671                  NaN                            NaN
# 672                  NaN                            NaN
# 673  Great Boughton Ward                      E05008675
#
#     Retrieved for use in GrantNav  \
# 629     2018-11-06T08:33:03+00:00
# 670     2018-11-06T08:33:03+00:00
# 671     2018-11-06T08:33:03+00:00
# 672     2018-11-06T08:33:03+00:00
# 673     2018-11-06T08:31:44+00:00
#
#                                License (see note)  \
# 629  https://creativecommons.org/licenses/by/4.0/
# 670  https://creativecommons.org/licenses/by/4.0/
# 671  https://creativecommons.org/licenses/by/4.0/
# 672  https://creativecommons.org/licenses/by/4.0/
# 673  https://creativecommons.org/licenses/by/4.0/
#
#      Note, this file also contains OS data © Crown copyright and database right 2016, Royal Mail data © Royal Mail copyright and Database right 2016, National Statistics data © Crown copyright and database right 2015 & 2016, see http://grantnav.threesixtygiving.org/datasets/ for more information.  \
# 629                                                NaN
# 670                                                NaN
# 671                                                NaN
# 672                                                NaN
# 673                                                NaN
#
#      Award Year
# 629        2018
# 670        2018
# 671        2018
# 672        2018
# 673        2017

# %%
aggregagations = {'Identifier': 'count',      
                  'Amount Awarded': 'sum'}

themes_pivot_df = pd.pivot_table(df, index=['Funding Org:Name', 'Award Year', 'Recipient District Geographic Code'], aggfunc = aggregagations)
#themes_pivot_df = pd.pivot_table(df, index=['Funding Org:Name', 'Award Year'], aggfunc = aggregagations)
themes_pivot_df.reset_index(inplace=True)

# %%
themes_pivot_df.head()
# Out:
#        Funding Org:Name  Award Year Recipient District Geographic Code  \
# 0  A B Charitable Trust        2013                          E06000002
# 1  A B Charitable Trust        2013                          E06000010
# 2  A B Charitable Trust        2013                          E06000018
# 3  A B Charitable Trust        2013                          E06000023
# 4  A B Charitable Trust        2013                          E06000028
#
#    Amount Awarded  Identifier
# 0         10000.0           1
# 1         17500.0           2
# 2         10000.0           1
# 3         17500.0           2
# 4          7500.0           1

# %%
out = '[' + themes_pivot_df.to_json(orient='records')[1:-1] + ']'
with open('../data/deprivation/grants_by_lad_donor_year.json', 'w') as f:
    f.write(out)

# %% [markdown]
# ## Aggregated deprivation by LAD

# %%
aggregagations = {'Identifier': 'count',      
                  'Amount Awarded': 'sum'}

lad_award_pivot_df = pd.pivot_table(themes_pivot_df, index=['Recipient District Geographic Code'], aggfunc = aggregagations)
#themes_pivot_df = pd.pivot_table(df, index=['Funding Org:Name', 'Award Year'], aggfunc = aggregagations)
lad_award_pivot_df.reset_index(inplace=True)

# %%
lad_award_pivot_df.head()
# Out:
#   Recipient District Geographic Code  Amount Awarded  Identifier
# 0                          E06000001      7337381.97          37
# 1                          E06000002     20286611.52          46
# 2                          E06000003     11997350.98          47
# 3                          E06000004     20367758.38          43
# 4                          E06000005      9436088.31          42

# %% [markdown]
# ## Merge with LAD deprivation data

# %%
lad_vars = [
    {'sheet': 'IMD', 'col': 'IMD - Average score'},
    {'sheet': 'Income', 'col': 'Income - Average score'},
    {'sheet': 'Employment', 'col': 'Employment - Average score'},
    {'sheet': 'Education', 'col': 'Education, Skills and Training - Average score'},
    {'sheet': 'Health', 'col': 'Health Deprivation and Disability - Average score'},
    {'sheet': 'Crime', 'col': 'Crime - Average score'},
    {'sheet': 'Barriers', 'col': 'Barriers to Housing and Services - Average score'},
    {'sheet': 'Living', 'col': 'Living Environment - Average score'}
]

# %%
lad_df = pd.DataFrame()

# %%
for i, v in enumerate(lad_vars):
    #print(v['sheet'],i)
    df = pd.read_excel('../data/deprivation/File_10_ID2015_Local_Authority_District_Summaries.xlsx', sheet_name=v['sheet'])
    df.rename(index=str, columns={'Local Authority District code (2013)' : 'LAD2013_CD', \
        'Local Authority District name (2013)' : 'LAD2013_NM', \
        v['col'] : v['sheet']+'_avg_score', \
        }, inplace=True)
    if i == 0:
        lad_df = lad_df.append(df[['LAD2013_CD','LAD2013_NM',v['sheet']+'_avg_score']])
    else:
        lad_df = pd.merge(lad_df, df[['LAD2013_CD',v['sheet']+'_avg_score']], on='LAD2013_CD',sort=True)
    
#dp_lad_df = pd.read_excel('../data/deprivation/File_10_ID2015_Local_Authority_District_Summaries.xlsx', sheet_name='ID2015 Domains', index_col=[0])

display(lad_df.head())
# Out:
#   LAD2013_CD            LAD2013_NM  IMD_avg_score  Income_avg_score  \
# 0  E06000001            Hartlepool         33.178             0.239
# 1  E06000002         Middlesbrough         40.216             0.268
# 2  E06000003  Redcar and Cleveland         28.567             0.204
# 3  E06000004      Stockton-on-Tees         24.625             0.177
# 4  E06000005            Darlington         23.639             0.168
#
#    Employment_avg_score  Education_avg_score  Health_avg_score  \
# 0                 0.211               30.510             0.929
# 1                 0.216               40.640             1.195
# 2                 0.186               27.875             0.752
# 3                 0.156               24.637             0.548
# 4                 0.150               22.569             0.502
#
#    Crime_avg_score  Barriers_avg_score  Living_avg_score
# 0            0.078              13.128             8.260
# 1            0.633              18.316            12.907
# 2           -0.013              12.863             7.923
# 3           -0.263              17.844             7.068
# 4            0.224              12.346            10.710

# %%
combined_gpd = pd.DataFrame()
combined_gpd = pd.merge(lad_award_pivot_df, lad_df, \
                  left_on='Recipient District Geographic Code', right_on='LAD2013_CD',sort=True)

# %%
combined_gpd.head()
# Out:
#   Recipient District Geographic Code  Amount Awarded  Identifier LAD2013_CD  \
# 0                          E06000001      7337381.97          37  E06000001
# 1                          E06000002     20286611.52          46  E06000002
# 2                          E06000003     11997350.98          47  E06000003
# 3                          E06000004     20367758.38          43  E06000004
# 4                          E06000005      9436088.31          42  E06000005
#
#              LAD2013_NM  IMD_avg_score  Income_avg_score  \
# 0            Hartlepool         33.178             0.239
# 1         Middlesbrough         40.216             0.268
# 2  Redcar and Cleveland         28.567             0.204
# 3      Stockton-on-Tees         24.625             0.177
# 4            Darlington         23.639             0.168
#
#    Employment_avg_score  Education_avg_score  Health_avg_score  \
# 0                 0.211               30.510             0.929
# 1                 0.216               40.640             1.195
# 2                 0.186               27.875             0.752
# 3                 0.156               24.637             0.548
# 4                 0.150               22.569             0.502
#
#    Crime_avg_score  Barriers_avg_score  Living_avg_score
# 0            0.078              13.128             8.260
# 1            0.633              18.316            12.907
# 2           -0.013              12.863             7.923
# 3           -0.263              17.844             7.068
# 4            0.224              12.346            10.710

# %%
out = '[' + combined_gpd.to_json(orient='records')[1:-1] + ']'
with open('../data/deprivation/grants_by_lad_deprivation.json', 'w') as f:
    f.write(out)
